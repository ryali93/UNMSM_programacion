# %% [markdown]
# <a href="https://colab.research.google.com/github/ryali93/UNMSM_programacion2019-1/blob/master/clase03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 2. Análisis de datos con Pandas

# %% [markdown]
#  La librería Pandas desarrollada para el análisis. Fue desarrollada en NumPy. La librería Pandas trae la riqueza de R al mundo de Python. Tiene eficiente estructuras de datos para procesar los datos, unir datos y leerlos de varias fuentes.

# %% [markdown]
# # 2.1. Data Frames

# %% [markdown]
# Importar y exportar datos en formato csv

# %%
import pandas as pd

# %%
import sys
sys.path
# Out:
# ['',
#  '/env/python',
#  '/usr/lib/python36.zip',
#  '/usr/lib/python3.6',
#  '/usr/lib/python3.6/lib-dynload',
#  '/usr/local/lib/python3.6/dist-packages',
#  '/usr/lib/python3/dist-packages',
#  '/usr/local/lib/python3.6/dist-packages/IPython/extensions',
#  '/root/.ipython']

# %%
# Importar datos en formato csv.
d = pd.read_csv('../data/students.csv')

# %%
# Leer los primeros registros
d.head()
# Out:
#    LOCATION CODE  COUNTY                                        AREA NAME  \
# 0          10402  ALBANY  RAVENA COEYMANS SELKIRK CENTRAL SCHOOL DISTRICT
# 1          10402  ALBANY  RAVENA COEYMANS SELKIRK CENTRAL SCHOOL DISTRICT
# 2          10402  ALBANY  RAVENA COEYMANS SELKIRK CENTRAL SCHOOL DISTRICT
# 3          10500  ALBANY                      COHOES CITY SCHOOL DISTRICT
# 4          10500  ALBANY                      COHOES CITY SCHOOL DISTRICT
#
#                   REGION SCHOOL YEARS  NO. OVERWEIGHT PCT OVERWEIGHT  \
# 0  NORTHEASTERN NEW YORK    2012-2013           124.0          18.5%
# 1  NORTHEASTERN NEW YORK    2012-2013            74.0          19.2%
# 2  NORTHEASTERN NEW YORK    2012-2013            50.0          17.6%
# 3  NORTHEASTERN NEW YORK    2012-2013            84.0          17.2%
# 4  NORTHEASTERN NEW YORK    2012-2013            58.0          16.1%
#
#    NO. OBESE PCT OBESE  NO. OVERWEIGHT OR OBESE PCT OVERWEIGHT OR OBESE  \
# 0      139.0     20.8%                    263.0                   39.3%
# 1       72.0     18.7%                    146.0                   37.9%
# 2       67.0     23.6%                    117.0                   41.2%
# 3      124.0     25.4%                    208.0                   42.5%
# 4       89.0     24.7%                    147.0                   40.8%
#
#       GRADE LEVEL        AREA TYPE  STREET ADDRESS    CITY STATE  ZIP CODE  \
# 0  DISTRICT TOTAL  SCHOOL DISTRICT  15 MOUNTAIN RD  RAVENA    NY   12143.0
# 1      ELEMENTARY  SCHOOL DISTRICT  15 MOUNTAIN RD  RAVENA    NY   12143.0
# 2     MIDDLE/HIGH  SCHOOL DISTRICT  15 MOUNTAIN RD  RAVENA    NY   12143.0
# 3  DISTRICT TOTAL  SCHOOL DISTRICT      7 BEVAN ST  COHOES    NY   12047.0
# 4      ELEMENTARY  SCHOOL DISTRICT      7 BEVAN ST  COHOES    NY   12047.0
#
#                                           Location 1
# 0  15 MOUNTAIN RD\nRAVENA, NY 12143\n(42.47227638...
# 1  15 MOUNTAIN RD\nRAVENA, NY 12143\n(42.47227638...
# 2  15 MOUNTAIN RD\nRAVENA, NY 12143\n(42.47227638...
# 3  7 BEVAN ST\nCOHOES, NY 12047\n(42.771285452000...
# 4  7 BEVAN ST\nCOHOES, NY 12047\n(42.771285452000...

# %%
d[0:5]['AREA NAME']
# Out:
# 0    RAVENA COEYMANS SELKIRK CENTRAL SCHOOL DISTRICT
# 1    RAVENA COEYMANS SELKIRK CENTRAL SCHOOL DISTRICT
# 2    RAVENA COEYMANS SELKIRK CENTRAL SCHOOL DISTRICT
# 3                        COHOES CITY SCHOOL DISTRICT
# 4                        COHOES CITY SCHOOL DISTRICT
# Name: AREA NAME, dtype: object

# %%
d['AREA NAME'][0:5]
# Out:
# 0    RAVENA COEYMANS SELKIRK CENTRAL SCHOOL DISTRICT
# 1    RAVENA COEYMANS SELKIRK CENTRAL SCHOOL DISTRICT
# 2    RAVENA COEYMANS SELKIRK CENTRAL SCHOOL DISTRICT
# 3                        COHOES CITY SCHOOL DISTRICT
# 4                        COHOES CITY SCHOOL DISTRICT
# Name: AREA NAME, dtype: object

# %%
df = d[0:5]['AREA NAME']
df
# Out:
# 0    RAVENA COEYMANS SELKIRK CENTRAL SCHOOL DISTRICT
# 1    RAVENA COEYMANS SELKIRK CENTRAL SCHOOL DISTRICT
# 2    RAVENA COEYMANS SELKIRK CENTRAL SCHOOL DISTRICT
# 3                        COHOES CITY SCHOOL DISTRICT
# 4                        COHOES CITY SCHOOL DISTRICT
# Name: AREA NAME, dtype: object

# %%
df.to_csv('sample_data.csv')

# %% [markdown]
# # 2.5. Importar y exportar datos en formato xls

# %%
# Importar datos en formato xls.
d = pd.read_excel('../0_Data/students.xls')

# %%
d.head()
# Out:
#    LOCATION CODE  COUNTY                                        AREA NAME  \
# 0          10402  ALBANY  RAVENA COEYMANS SELKIRK CENTRAL SCHOOL DISTRICT
# 1          10402  ALBANY  RAVENA COEYMANS SELKIRK CENTRAL SCHOOL DISTRICT
# 2          10402  ALBANY  RAVENA COEYMANS SELKIRK CENTRAL SCHOOL DISTRICT
# 3          10500  ALBANY                      COHOES CITY SCHOOL DISTRICT
# 4          10500  ALBANY                      COHOES CITY SCHOOL DISTRICT
#
#                   REGION SCHOOL YEARS  NO. OVERWEIGHT  PCT OVERWEIGHT  \
# 0  NORTHEASTERN NEW YORK    2012-2013           124.0           0.185
# 1  NORTHEASTERN NEW YORK    2012-2013            74.0           0.192
# 2  NORTHEASTERN NEW YORK    2012-2013            50.0           0.176
# 3  NORTHEASTERN NEW YORK    2012-2013            84.0           0.172
# 4  NORTHEASTERN NEW YORK    2012-2013            58.0           0.161
#
#    NO. OBESE  PCT OBESE  NO. OVERWEIGHT OR OBESE  PCT OVERWEIGHT OR OBESE  \
# 0      139.0      0.208                    263.0                    0.393
# 1       72.0      0.187                    146.0                    0.379
# 2       67.0      0.236                    117.0                    0.412
# 3      124.0      0.254                    208.0                    0.425
# 4       89.0      0.247                    147.0                    0.408
#
#       GRADE LEVEL        AREA TYPE  STREET ADDRESS    CITY STATE  ZIP CODE  \
# 0  DISTRICT TOTAL  SCHOOL DISTRICT  15 MOUNTAIN RD  RAVENA    NY   12143.0
# 1      ELEMENTARY  SCHOOL DISTRICT  15 MOUNTAIN RD  RAVENA    NY   12143.0
# 2     MIDDLE/HIGH  SCHOOL DISTRICT  15 MOUNTAIN RD  RAVENA    NY   12143.0
# 3  DISTRICT TOTAL  SCHOOL DISTRICT      7 BEVAN ST  COHOES    NY   12047.0
# 4      ELEMENTARY  SCHOOL DISTRICT      7 BEVAN ST  COHOES    NY   12047.0
#
#                                           Location 1
# 0  15 MOUNTAIN RD\nRAVENA, NY 12143\n(42.47227638...
# 1  15 MOUNTAIN RD\nRAVENA, NY 12143\n(42.47227638...
# 2  15 MOUNTAIN RD\nRAVENA, NY 12143\n(42.47227638...
# 3  7 BEVAN ST\nCOHOES, NY 12047\n(42.771285452000...
# 4  7 BEVAN ST\nCOHOES, NY 12047\n(42.771285452000...

# %%
# Exportar datos de un data frame a un xls
df.to_excel('sample_data.xls')

# %% [markdown]
# # 2.6. Importar datos en formato JSON

# %%
# Importar el paquete JSON.
import json

# %%
json_data = open('../0_Data/students.json')

# %%
data = json.load(json_data)

# %%
data
# Out:
# {'meta': {'view': {'id': 'es3k-2aus',
#    'name': 'Student Weight Status Category Reporting Results: Beginning 2010',
#    'attribution': 'New York State Department of Health',
#    'attributionLink': 'http://www.health.ny.gov/prevention/obesity/',
#    'averageRating': 0,
#    'category': 'Health',
#    'createdAt': 1363701898,
#    'description': 'The Student Weight Status Category Reporting System (SWSCR) collects weight status category data (underweight, healthy weight, overweight or obese, based on BMI-for-age percentile).  The dataset includes separate estimates of the percent of students overweight, obese and overweight or obese for all reportable grades within the county and/or region and by grade groups (elementary and middle/high).   The rates of overweight and obesity reported are percentages based on counts of students in selected grades (Pre-K, K, 2, 4, 7, 10) reported to the NYSDOH. Because these rates reflect a broad range of factors that vary by school district, to make comparisons about observed differences in the rates of obesity and overweight between school districts requires the use of multivariate statistics. County, regional and statewide estimates will only be provided biennially, District estimates will be updated annually. For more information check out http://www.health.ny.gov/prevention/obesity/, see our Instruction Guide on How to Create Visualizations https://health.data.ny.gov/api/assets/6490BDA9-AE4D-406F-BA5A-703793526B9F or go to the "About" tab.',
#    'displayType': 'table',
#    'downloadCount': 5949,
#    'indexUpdatedAt': 1414628645,
#    'newBackend': False,
#    'numberOfComments': 0,
#    'oid': 8927251,
#    'publicationAppendEnabled': False,
#    'publicationDate': 1411499050,
#    'publicationGroup': 742658,
#    'publicationStage': 'published',
#    'rowsUpdatedAt': 1411498834,
#    'rowsUpdatedBy': 'da2s-ec8k',
#    'tableId': 1726367,
#    'totalTimesRated': 0,
#    'viewCount': 17054,
#    'viewLastModified': 1411499050,
#    'viewType': 'tabular',
#    'columns': [{'id': -1,
#      'name': 'sid',
#      'dataTypeName': 'meta_data',
#      'fieldName': ':sid',
#      'position': 0,
#      'renderTypeName': 'meta_data',
#      'format': {}},
#     {'id': -1,
#      'name': 'id',
#      'dataTypeName': 'meta_data',
#      'fieldName': ':id',
#      'position': 0,
#      'renderTypeName': 'meta_data',
#      'format': {}},
#     {'id': -1,
#      'name': 'position',
#      'dataTypeName': 'meta_data',
#      'fieldName': ':position',
#      'position': 0,
#      'renderTypeName': 'meta_data',
#      'format': {}},
#     {'id': -1,
#      'name': 'created_at',
#      'dataTypeName': 'meta_data',
#      'fieldName': ':created_at',
#      'position': 0,
#      'renderTypeName': 'meta_data',
#      'format': {}},
#     {'id': -1,
#      'name': 'created_meta',
#      'dataTypeName': 'meta_data',
#      'fieldName': ':created_meta',
#      'position': 0,
#      'renderTypeName': 'meta_data',
#      'format': {}},
#     {'id': -1,
#      'name': 'updated_at',
#      'dataTypeName': 'meta_data',
#      'fieldName': ':updated_at',
#      'position': 0,
#      'renderTypeName': 'meta_data',
#      'format': {}},
#     {'id': -1,
#      'name': 'updated_meta',
#      'dataTypeName': 'meta_data',
#      'fieldName': ':updated_meta',
#      'position': 0,
#      'renderTypeName': 'meta_data',
#      'format': {}},
#     {'id': -1,
#      'name': 'meta',
#      'dataTypeName': 'meta_data',
#      'fieldName': ':meta',
#      'position': 0,
#      'renderTypeName': 'meta_data',
#      'format': {}},
#     {'id': 168098713,
#      'name': 'LOCATION CODE',
#      'dataTypeName': 'text',
#      'description': '6-digit code identifying the location type. For school districts, this is the 6-digit NYSED district BEDS code. For counties, this is the 6-digit NYSED county code. Regional codes range from 100000 â€“ 700000. Statewide = 000000. ',
#      'fieldName': 'location_code',
#      'position': 1,
#      'renderTypeName': 'text',
#      'tableColumnId': 8751874,
#      'width': 130,
#      'cachedContents': {'non_null': 3270,
#       'smallest': '000000',
#       'null': 0,
#       'largest': '700000',
#       'top': [{'count': 20, 'item': '660102'},
#        {'count': 19, 'item': '660202'},
#        {'count': 18, 'item': '660203'},
#        {'count': 17, 'item': '660303'},
#        {'count': 16, 'item': '660402'},
#        {'count': 15, 'item': '660403'},
#        {'count': 14, 'item': '660404'},
#        {'count': 13, 'item': '660405'},
#        {'count': 12, 'item': '660407'},
#        {'count': 11, 'item': '660501'},
#        {'count': 10, 'item': '660801'},
#        {'count': 9, 'item': '660805'},
#        {'count': 8, 'item': '660809'},
#        {'count': 7, 'item': '660900'},
#        {'count': 6, 'item': '661100'},
#        {'count': 5, 'item': '661301'},
#        {'count': 4, 'item': '661601'},
#        {'count': 3, 'item': '661901'},
#        {'count': 2, 'item': '662001'},
#        {'count': 1, 'item': '662101'}]},
#      'format': {'align': 'left'}},
#     {'id': 168098714,
#      'name': 'COUNTY',
#      'dataTypeName': 'text',
#      'description': 'NYS county',
#      'fieldName': 'county',
#      'position': 2,
#      'renderTypeName': 'text',
#      'tableColumnId': 8751875,
#      'width': 128,
#      'cachedContents': {'non_null': 3270,
#       'smallest': 'ALBANY',
#       'null': 0,
#       'largest': 'YATES',
#       'top': [{'count': 20, 'item': 'ALBANY'},
#        {'count': 19, 'item': 'ALLEGANY'},
#        {'count': 18, 'item': 'BROOME'},
#        {'count': 17, 'item': 'CATTARAUGUS'},
#        {'count': 16, 'item': 'CHAUTAUQUA'},
#        {'count': 15, 'item': 'DELAWARE'},
#        {'count': 14, 'item': 'DUTCHESS'},
#        {'count': 13, 'item': 'ERIE'},
#        {'count': 12, 'item': 'MONROE'},
#        {'count': 11, 'item': 'NASSAU'},
#        {'count': 10, 'item': 'ONEIDA'},
#        {'count': 9, 'item': 'ONONDAGA'},
#        {'count': 8, 'item': 'ORANGE'},
#        {'count': 7, 'item': 'ST. LAWRENCE'},
#        {'count': 6, 'item': 'STEUBEN'},
#        {'count': 5, 'item': 'SUFFOLK'},
#        {'count': 4, 'item': 'WASHINGTON'},
#        {'count': 3, 'item': 'WAYNE'},
#        {'count': 2, 'item': 'WESTCHESTER'},
#        {'count': 1, 'item': 'N/A'}]},
#      'format': {'align': 'left'}},
#     {'id': 168098715,
#      'name': 'AREA NAME',
#      'dataTypeName': 'text',
#      'description': 'School district, county, or region name',
#      'fieldName': 'area_name',
#      'position': 3,
#      'renderTypeName': 'text',
#      'tableColumnId': 8751876,
#      'width': 208,
#      'cachedContents': {'non_null': 3270,
#       'smallest': 'ADDISON CENTRAL SCHOOL',
#       'null': 0,
#       'largest': 'YORKTOWN CENTRAL SCHOOL',
#       'top': [{'count': 20, 'item': 'BEDFORD CENTRAL SCHOOL'},
#        {'count': 19, 'item': 'CROTON HARMON U F S'},
#        {'count': 18, 'item': 'HENDRICK HUDSON CENTRAL SCHOOL'},
#        {'count': 17, 'item': 'BRONXVILLE UNION FREE SCHOOL'},
#        {'count': 16, 'item': 'IRVINGTON UNION FREE SCHOOL'},
#        {'count': 15, 'item': 'DOBBS FERRY UNION FREE SCHOOL'},
#        {'count': 14, 'item': 'HASTINGS ON HUDSON U F S'},
#        {'count': 13, 'item': 'ARDSLEY UNION FREE SCHOOL'},
#        {'count': 12, 'item': 'GREENBURGH CENTRAL SCHOOL'},
#        {'count': 11, 'item': 'HARRISON CENTRAL SCHOOL'},
#        {'count': 10, 'item': 'MT PLEASANT CENTRAL SCHOOL'},
#        {'count': 9, 'item': 'VALHALLA UNION FREE SCHOOL'},
#        {'count': 8, 'item': 'PLEASANTVILLE U F S'},
#        {'count': 7, 'item': 'MOUNT VERNON CITY SCHOOLS'},
#        {'count': 6, 'item': 'NEW ROCHELLE CITY SCHOOLS'},
#        {'count': 5, 'item': 'NORTH SALEM CENTRAL SCHOOL DISTRICT'},
#        {'count': 4, 'item': 'PELHAM UNION FREE SCHOOL'},
#        {'count': 3, 'item': 'RYE NECK UNION FREE SCHOOL'},
#        {'count': 2, 'item': 'SCARSDALE UNION FREE SCHOOL'},
#        {'count': 1, 'item': 'SOMERS CENTRAL SCHOOL'}]},
#      'format': {'align': 'left'}},
#     {'id': 168098716,
#      'name': 'REGION',
#      'dataTypeName': 'text',
#      'description': 'NYS region',
#      'fieldName': 'region',
#      'position': 4,
#      'renderTypeName': 'text',
#      'tableColumnId': 8751877,
#      'width': 172,
#      'cachedContents': {'non_null': 3270,
#       'smallest': 'CENTRAL NEW YORK',
#       'null': 0,
#       'largest': 'WESTERN NEW YORK',
#       'top': [{'count': 20, 'item': 'NORTHEASTERN NEW YORK'},
#        {'count': 19, 'item': 'WESTERN NEW YORK'},
#        {'count': 18, 'item': 'NEW YORK - PENN'},
#        {'count': 17, 'item': 'CENTRAL NEW YORK'},
#        {'count': 16, 'item': 'FINGER LAKES'},
#        {'count': 15, 'item': 'HUDSON VALLEY'},
#        {'count': 14, 'item': 'NASSAU-SUFFOLK'},
#        {'count': 13, 'item': 'STATEWIDE (EXCLUDING NYC)'}]},
#      'format': {'align': 'left'}},
#     {'id': 168098717,
#      'name': 'SCHOOL YEARS',
#      'dataTypeName': 'text',
#      'description': 'School years covered by reporting cycle',
#      'fieldName': 'school_years',
#      'position': 5,
#      'renderTypeName': 'text',
#      'tableColumnId': 8751878,
#      'width': 133,
#      'cachedContents': {'non_null': 3270,
#       'smallest': '2010-2012',
#       'null': 0,
#       'largest': '2012-2013',
#       'top': [{'count': 20, 'item': '2010-2012'},
#        {'count': 19, 'item': '2012-2013'}]},
#      'format': {'align': 'left'}},
#     {'id': 168098718,
#      'name': 'NO. OVERWEIGHT',
#      'dataTypeName': 'number',
#      'description': 'Number of students in 85th to 94th percentile (Overweight).  For children aged 2-19 years of age, overweight and obese are defined by plotting calculated Body-Mass Index (BMI).',
#      'fieldName': 'overweight_1',
#      'position': 6,
#      'renderTypeName': 'number',
#      'tableColumnId': 8751879,
#      'width': 119,
#      'cachedContents': {'non_null': 3078,
#       'smallest': '5',
#       'sum': '704192',
#       'null': 192,
#       'average': '228.7823261858350',
#       'largest': '77813',
#       'top': [{'count': 20, 'item': '10'},
#        {'count': 19, 'item': '14'},
#        {'count': 18, 'item': '34'},
#        {'count': 17, 'item': '25'},
#        {'count': 16, 'item': '24'},
#        {'count': 15, 'item': '33'},
#        {'count': 14, 'item': '26'},
#        {'count': 13, 'item': '65'},
#        {'count': 12, 'item': '39'},
#        {'count': 11, 'item': '86'},
#        {'count': 10, 'item': '64'},
#        {'count': 9, 'item': '31'},
#        {'count': 8, 'item': '35'},
#        {'count': 7, 'item': '289'},
#        {'count': 6, 'item': '206'},
#        {'count': 5, 'item': '83'},
#        {'count': 4, 'item': '613'},
#        {'count': 3, 'item': '343'},
#        {'count': 2, 'item': '270'},
#        {'count': 1, 'item': '48'}]},
#      'format': {'precisionStyle': 'standard',
#       'align': 'right',
#       'noCommas': 'false'}},
#     {'id': 168098719,
#      'name': 'PCT OVERWEIGHT',
#      'dataTypeName': 'percent',
#      'description': 'Percentage of students in 85th to 94th percentile (Overweight).  For children aged 2-19 years of age, overweight and obese are defined by plotting calculated Body-Mass Index (BMI).',
#      'fieldName': 'overweight_2',
#      'position': 7,
#      'renderTypeName': 'percent',
#      'tableColumnId': 8751880,
#      'width': 123,
#      'cachedContents': {'non_null': 3078,
#       'smallest': '1.6',
#       'sum': '51402.4',
#       'null': 192,
#       'average': '16.69993502274204',
#       'largest': '100.0',
#       'top': [{'count': 20, 'item': '15.5'},
#        {'count': 19, 'item': '17.1'},
#        {'count': 18, 'item': '16.6'},
#        {'count': 17, 'item': '18.3'},
#        {'count': 16, 'item': '16.7'},
#        {'count': 15, 'item': '11.0'},
#        {'count': 14, 'item': '12.2'},
#        {'count': 13, 'item': '12.9'},
#        {'count': 12, 'item': '15.1'},
#        {'count': 11, 'item': '14.7'},
#        {'count': 10, 'item': '13.3'},
#        {'count': 9, 'item': '11.6'},
#        {'count': 8, 'item': '17.2'},
#        {'count': 7, 'item': '15.8'},
#        {'count': 6, 'item': '17.0'},
#        {'count': 5, 'item': '13.5'},
#        {'count': 4, 'item': '16.9'},
#        {'count': 3, 'item': '15.6'},
#        {'count': 2, 'item': '18.9'},
#        {'count': 1, 'item': '12.0'}]},
#      'format': {'view': 'percent_bar_and_text',
#       'align': 'right',
#       'noCommas': 'false'}},
#     {'id': 168098720,
#      'name': 'NO. OBESE',
#      'dataTypeName': 'number',
#      'description': 'Number of students at or above the 95th percentile (Obese).  For children aged 2-19 years of age, overweight and obese are defined by plotting calculated Body-Mass Index (BMI).',
#      'fieldName': 'obese_1',
#      'position': 8,
#      'renderTypeName': 'number',
#      'tableColumnId': 8751881,
#      'width': 84,
#      'cachedContents': {'non_null': 3072,
#       'smallest': '5',
#       'sum': '760955',
#       'null': 198,
#       'average': '247.7067057291667',
#       'largest': '84578',
#       'top': [{'count': 20, 'item': '17'},
#        {'count': 19, 'item': '30'},
#        {'count': 18, 'item': '24'},
#        {'count': 17, 'item': '5'},
#        {'count': 16, 'item': '41'},
#        {'count': 15, 'item': '23'},
#        {'count': 14, 'item': '37'},
#        {'count': 13, 'item': '28'},
#        {'count': 12, 'item': '35'},
#        {'count': 11, 'item': '21'},
#        {'count': 10, 'item': '27'},
#        {'count': 9, 'item': '19'},
#        {'count': 8, 'item': '31'},
#        {'count': 7, 'item': '63'},
#        {'count': 6, 'item': '26'},
#        {'count': 5, 'item': '84'},
#        {'count': 4, 'item': '40'},
#        {'count': 3, 'item': '44'},
#        {'count': 2, 'item': '57'},
#        {'count': 1, 'item': '32'}]},
#      'format': {'precisionStyle': 'standard',
#       'align': 'right',
#       'noCommas': 'false'}},
#     {'id': 168098721,
#      'name': 'PCT OBESE',
#      'dataTypeName': 'percent',
#      'description': 'Percentage of students at or above the 95th percentile (Obese).  For children aged 2-19 years of age, overweight and obese are defined by plotting calculated Body-Mass Index (BMI).',
#      'fieldName': 'obese_2',
#      'position': 9,
#      'renderTypeName': 'percent',
#      'tableColumnId': 8751882,
#      'width': 87,
#      'cachedContents': {'non_null': 3072,
#       'smallest': '1.3',
#       'sum': '56795.5',
#       'null': 198,
#       'average': '18.48811848958333',
#       'largest': '100.0',
#       'top': [{'count': 20, 'item': '10.7'},
#        {'count': 19, 'item': '14.3'},
#        {'count': 18, 'item': '11.5'},
#        {'count': 17, 'item': '12.1'},
#        {'count': 16, 'item': '8.6'},
#        {'count': 15, 'item': '11.8'},
#        {'count': 14, 'item': '16.2'},
#        {'count': 13, 'item': '16.1'},
#        {'count': 12, 'item': '16.4'},
#        {'count': 11, 'item': '18.5'},
#        {'count': 10, 'item': '19.0'},
#        {'count': 9, 'item': '17.8'},
#        {'count': 8, 'item': '10.0'},
#        {'count': 7, 'item': '7.9'},
#        {'count': 6, 'item': '13.6'},
#        {'count': 5, 'item': '10.2'},
#        {'count': 4, 'item': '10.3'},
#        {'count': 3, 'item': '10.1'},
#        {'count': 2, 'item': '9.6'},
#        {'count': 1, 'item': '11.7'}]},
#      'format': {'view': 'percent_bar_and_text',
#       'align': 'right',
#       'noCommas': 'false'}},
#     {'id': 168098722,
#      'name': 'NO. OVERWEIGHT OR OBESE',
#      'dataTypeName': 'number',
#      'description': 'Number of students at or above the 85th percentile (Overweight or obese).  For children aged 2-19 years of age, overweight and obese are defined by plotting calculated Body-Mass Index (BMI).',
#      'fieldName': 'overweight_or_obese_1',
#      'position': 10,
#      'renderTypeName': 'number',
#      'tableColumnId': 8751883,
#      'width': 191,
#      'cachedContents': {'non_null': 3124,
#       'smallest': '5',
#       'sum': '1465147',
#       'null': 146,
#       'average': '468.9971190781050',
#       'largest': '162391',
#       'top': [{'count': 20, 'item': '100'},
#        {'count': 19, 'item': '50'},
#        {'count': 18, 'item': '107'},
#        {'count': 17, 'item': '64'},
#        {'count': 16, 'item': '71'},
#        {'count': 15, 'item': '51'}]},
#      'format': {'precisionStyle': 'standard',
#       'align': 'right',
#       'noCommas': 'false'}},
#     {'id': 168098723,
#      'name': 'PCT OVERWEIGHT OR OBESE',
#      'dataTypeName': 'percent',
#      'description': 'Percentage of students at or above the 85th percentile (Overweight or obese).  For children aged 2-19 years of age, overweight and obese are defined by plotting calculated Body-Mass Index (BMI).',
#      'fieldName': 'overweight_or_obese_2',
#      'position': 11,
#      'renderTypeName': 'percent',
#      'tableColumnId': 8751884,
#      'width': 198,
#      'cachedContents': {'non_null': 3124,
#       'smallest': '3.6',
#       'sum': '108198.1',
#       'null': 146,
#       'average': '34.63447503201024',
#       'largest': '100.0',
#       'top': [{'count': 20, 'item': '38.3'},
#        {'count': 19, 'item': '32.0'},
#        {'count': 18, 'item': '21.0'},
#        {'count': 17, 'item': '28.4'},
#        {'count': 16, 'item': '37.3'},
#        {'count': 15, 'item': '44.9'},
#        {'count': 14, 'item': '46.1'},
#        {'count': 13, 'item': '43.2'}]},
#      'format': {'view': 'percent_bar_and_text',
#       'align': 'right',
#       'noCommas': 'false'}},
#     {'id': 168098724,
#      'name': 'GRADE LEVEL',
#      'dataTypeName': 'text',
#      'description': 'Grade category (Elementary (grades Pre-K, K, 2 & 4); Middle/high (grades 7 & 10); or District total (grades Pre-K, K, 2, 4, 7 & 10))',
#      'fieldName': 'grade_category',
#      'position': 12,
#      'renderTypeName': 'text',
#      'tableColumnId': 8751885,
#      'width': 151,
#      'cachedContents': {'non_null': 3270,
#       'smallest': 'DISTRICT TOTAL',
#       'null': 0,
#       'largest': 'MIDDLE/HIGH',
#       'top': [{'count': 20, 'item': 'DISTRICT TOTAL'},
#        {'count': 19, 'item': 'ELEMENTARY'},
#        {'count': 18, 'item': 'MIDDLE/HIGH'}]},
#      'format': {'align': 'left'}},
#     {'id': 168098725,
#      'name': 'AREA TYPE',
#      'dataTypeName': 'text',
#      'description': 'Area type definition (Statewide, excluding NYC; Region; County; School District)',
#      'fieldName': 'area_type',
#      'position': 13,
#      'renderTypeName': 'text',
#      'tableColumnId': 8751886,
#      'width': 208,
#      'cachedContents': {'non_null': 3270,
#       'smallest': 'COUNTY',
#       'null': 0,
#       'largest': 'STATEWIDE (EXCLUDING NYC)',
#       'top': [{'count': 20, 'item': 'SCHOOL DISTRICT'},
#        {'count': 19, 'item': 'COUNTY'},
#        {'count': 18, 'item': 'REGION'},
#        {'count': 17, 'item': 'STATEWIDE (EXCLUDING NYC)'}]},
#      'format': {'align': 'left'}},
#     {'id': 168098726,
#      'name': 'STREET ADDRESS',
#      'dataTypeName': 'text',
#      'description': 'Street address of school district home office',
#      'fieldName': 'street_address',
#      'position': 14,
#      'renderTypeName': 'text',
#      'tableColumnId': 8751888,
#      'width': 268,
#      'cachedContents': {'non_null': 3075,
#       'smallest': '1000 W BOSTON POST RD',
#       'null': 195,
#       'largest': 'S 5120 ORCHARD AVE'},
#      'format': {'align': 'left'}},
#     {'id': 168098727,
#      'name': 'CITY',
#      'dataTypeName': 'text',
#      'description': 'City of school district home office',
#      'fieldName': 'city',
#      'position': 15,
#      'renderTypeName': 'text',
#      'tableColumnId': 8751891,
#      'width': 148,
#      'cachedContents': {'non_null': 3075,
#       'smallest': 'ACCORD',
#       'null': 195,
#       'largest': 'YOUNGSTOWN',
#       'top': [{'count': 20, 'item': 'GREENLAWN'},
#        {'count': 19, 'item': 'SOUTHAMPTON'},
#        {'count': 18, 'item': 'BOLTON LANDING'},
#        {'count': 17, 'item': 'GLENS FALLS'},
#        {'count': 16, 'item': 'NORTH CREEK'},
#        {'count': 15, 'item': 'QUEENSBURY'},
#        {'count': 14, 'item': 'FORT ANN'},
#        {'count': 13, 'item': 'FORT EDWARD'},
#        {'count': 12, 'item': 'GRANVILLE'},
#        {'count': 11, 'item': 'GREENWICH'},
#        {'count': 10, 'item': 'LYONS'},
#        {'count': 9, 'item': 'MARION'},
#        {'count': 8, 'item': 'PALMYRA'},
#        {'count': 7, 'item': 'WOLCOTT'},
#        {'count': 6, 'item': 'RED CREEK'},
#        {'count': 5, 'item': 'BEDFORD'},
#        {'count': 4, 'item': 'CROTON ON HUDSON'},
#        {'count': 3, 'item': 'MONTROSE'},
#        {'count': 2, 'item': 'BRONXVILLE'},
#        {'count': 1, 'item': 'IRVINGTON'}]},
#      'format': {'align': 'left'}},
#     {'id': 168098728,
#      'name': 'STATE',
#      'dataTypeName': 'text',
#      'description': 'State of school district home office',
#      'fieldName': 'state',
#      'position': 16,
#      'renderTypeName': 'text',
#      'tableColumnId': 8751893,
#      'width': 68,
#      'cachedContents': {'non_null': 3075,
#       'smallest': 'NY',
#       'null': 195,
#       'largest': 'NY',
#       'top': [{'count': 20, 'item': 'NY'}]},
#      'format': {'align': 'left'}},
#     {'id': 168098729,
#      'name': 'ZIP CODE',
#      'dataTypeName': 'text',
#      'description': 'Zip code of school district home office',
#      'fieldName': 'zip_code',
#      'position': 17,
#      'renderTypeName': 'text',
#      'tableColumnId': 8751895,
#      'width': 82,
#      'cachedContents': {'non_null': 3075,
#       'smallest': '06390',
#       'null': 195,
#       'largest': '14905',
#       'top': [{'count': 20, 'item': '11772'},
#        {'count': 19, 'item': '11740'},
#        {'count': 18, 'item': '11968'},
#        {'count': 17, 'item': '12801'},
#        {'count': 16, 'item': '12853'},
#        {'count': 15, 'item': '12804'},
#        {'count': 14, 'item': '12827'},
#        {'count': 13, 'item': '12828'},
#        {'count': 12, 'item': '12832'},
#        {'count': 11, 'item': '12834'},
#        {'count': 10, 'item': '14489'},
#        {'count': 9, 'item': '14505'},
#        {'count': 8, 'item': '14522'},
#        {'count': 7, 'item': '14590'},
#        {'count': 6, 'item': '13143'},
#        {'count': 5, 'item': '10506'},
#        {'count': 4, 'item': '10520'},
#        {'count': 3, 'item': '10548'},
#        {'count': 2, 'item': '10708'},
#        {'count': 1, 'item': '10533'}]},
#      'format': {'align': 'left'}},
#     {'id': 168098732,
#      'name': 'Location 1',
#      'dataTypeName': 'location',
#      'description': 'Latitude and longitude of district home or county (blank for region and statewide)',
#      'fieldName': 'location_1',
#      'position': 20,
#      'renderTypeName': 'location',
#      'tableColumnId': 8751961,
#      'width': 100,
#      'cachedContents': {'non_null': 3246,
#       'smallest': {'longitude': '-76.33758908099963',
#        'latitude': '42.22755209000047',
#        'human_address': '{"address":"1 ACADEMY ST","city":"CANDOR","state":"NY","zip":"13743"}'},
#       'null': 24,
#       'largest': {'longitude': '-77.078311', 'latitude': '42.634338'},
#       'top': [{'count': 20,
#         'item': {'longitude': '-73.80889775999964',
#          'latitude': '41.03136647800045',
#          'human_address': '{"address":"475 W HARTSDALE AVE-ADMIN BLDG","city":"HARTSDALE","state":"NY","zip":"10530"}'}},
#        {'count': 19,
#         'item': {'longitude': '-73.71683523299964',
#          'latitude': '40.9797534060005',
#          'human_address': '{"address":"50 UNION AVE","city":"HARRISON","state":"NY","zip":"10528"}'}},
#        {'count': 18,
#         'item': {'longitude': '-73.76329651999964',
#          'latitude': '41.1130223400005',
#          'human_address': '{"address":"825 WESTLAKE DR","city":"THORNWOOD","state":"NY","zip":"10594"}'}},
#        {'count': 17,
#         'item': {'longitude': '-73.77740930199963',
#          'latitude': '41.09183251000047',
#          'human_address': '{"address":"316 COLUMBUS AVE","city":"VALHALLA","state":"NY","zip":"10595"}'}},
#        {'count': 16,
#         'item': {'longitude': '-73.78535361899964',
#          'latitude': '41.134073388000445',
#          'human_address': '{"address":"60 ROMER AVE","city":"PLEASANTVILLE","state":"NY","zip":"10570"}'}},
#        {'count': 15,
#         'item': {'longitude': '-73.82498386099962',
#          'latitude': '40.91735870400049',
#          'human_address': '{"address":"165 N COLUMBUS AVE","city":"MOUNT VERNON","state":"NY","zip":"10553"}'}},
#        {'count': 14,
#         'item': {'longitude': '-73.78680754599964',
#          'latitude': '40.91981170600047',
#          'human_address': '{"address":"515 NORTH AVE","city":"NEW ROCHELLE","state":"NY","zip":"10801"}'}},
#        {'count': 13,
#         'item': {'longitude': '-73.59371737799967',
#          'latitude': '41.35390968200045',
#          'human_address': '{"address":"230 JUNE RD","city":"NORTH SALEM","state":"NY","zip":"10560"}'}},
#        {'count': 12,
#         'item': {'longitude': '-73.81184542199964',
#          'latitude': '40.90393605200046',
#          'human_address': '{"address":"18 FRANKLIN PL","city":"PELHAM","state":"NY","zip":"10803"}'}},
#        {'count': 11,
#         'item': {'longitude': '-73.71648609199963',
#          'latitude': '40.957081109000455',
#          'human_address': '{"address":"310 HORNIDGE RD","city":"MAMARONECK","state":"NY","zip":"10543"}'}},
#        {'count': 10,
#         'item': {'longitude': '-73.79497681299966',
#          'latitude': '40.99481428600046',
#          'human_address': '{"address":"2 BREWSTER RD","city":"SCARSDALE","state":"NY","zip":"10583"}'}},
#        {'count': 9,
#         'item': {'longitude': '-73.68580075399967',
#          'latitude': '41.32741105800045',
#          'human_address': '{"address":"334 RT 202","city":"SOMERS","state":"NY","zip":"10589"}'}},
#        {'count': 8,
#         'item': {'longitude': '-78.11512027099968',
#          'latitude': '42.63018163000049',
#          'human_address': '{"address":"5550 SCHOOL RD","city":"GAINESVILLE","state":"NY","zip":"14066"}'}},
#        {'count': 7,
#         'item': {'longitude': '-78.09532573499968',
#          'latitude': '42.81989373200048',
#          'human_address': '{"address":"1225 RT 19","city":"WYOMING","state":"NY","zip":"14591"}'}},
#        {'count': 6,
#         'item': {'longitude': '-78.13730976199963',
#          'latitude': '42.74025680700049',
#          'human_address': '{"address":"153 W BUFFALO ST","city":"WARSAW","state":"NY","zip":"14569"}'}},
#        {'count': 5,
#         'item': {'longitude': '-76.97679374199964',
#          'latitude': '42.527728796000474',
#          'human_address': '{"address":"55 WATER ST","city":"DUNDEE","state":"NY","zip":"14837"}'}}]},
#      'format': {'view': 'coords', 'align': 'left'},
#      'subColumnTypes': ['human_address',
#       'latitude',
#       'longitude',
#       'machine_address',
#       'needs_recoding']}],
#    'grants': [{'inherited': False, 'type': 'viewer', 'flags': ['public']}],
#    'metadata': {'custom_fields': {'Notes': {'Notes': "The SWSCR dataset includes weight status data collected from all public school districts outside of the five boroughs of NYC. The dataset is a valid source of information about variation in overweight and obesity in public school districts outside of New York City.  However, because these rates reflect a broad range of factors that vary by school district, to make absolute comparisons about observed differences in the rates of obesity and overweight between school districts requires the use of multivariate statistics.  Data are aggregated to New York State Department of Education county code assigned to reporting schools and school districts, and to NYSDOH regions and statewide.  Because school district boundaries do not align with county or regional boundaries, the county- and regional-level estimates reflect data from students attending school within schools assigned a particular county or regional code.  County and regional assignment is not based on county or region of residence. The estimates represent the percentage of students reported within a weight status category, which reflects data reported to the Student Weight Status Category Reporting System. These data should not be considered to represent all school aged-children attending school in a district, county or region because of: restrictions in reporting due to FERPA, especially parents/guardians ability to request that their child's weight status data be excluded from reporting and other sources of missing data.  o\tUse the school years variable to distinguish between the full file (which spans 2 years and includes all public school districts) and the single-year, district only file (which spans a single year and includes only the approximately 50% of public school districts that reported during that year). County, regional and statewide estimates will only be provided biennially with the full-year file. District estimates will be updated annually. "},
#      'Dataset Summary': {'Granularity': 'Public school district',
#       'Coverage': 'Statewide, exclusive of the five boroughs of New York City',
#       'Posting Frequency': 'Full data set with all estimates released biennially, district-level single year file released annually (contains data on approximately 50% of school districts)',
#       'Data Frequency': 'Annually',
#       'Units': 'Percentages, Counts',
#       'Dataset Owner': 'Bureau of Chronic Disease Evaluation and Research, Division of Chronic Disease Prevention',
#       'Organization': 'Center for Community Health',
#       'Time Period': 'Beginning 2010'},
#      'Disclaimers': {'Limitations': 'Because of restrictions in reporting due to the Family Educational Rights and Privacy Act (FERPA) there was some variation in how much of the student population was represented in the data schools submitted to SWSCR, especially among smaller school districts. Therefore the percentage of the student population represented in the district, county and regional-level estimates may vary. New York City school districts are exempt from the NYS Education Law 903 and 904 that established the SWSCR system. Therefore this dataset excludes public school districts from the five boroughs of New York City (Brooklyn, Kings, New York, Queens, and Richmond). BOCES, special act schools (4201 designated schools), charter, and private schools are also excluded. '},
#      'Additional Resources': {'See Also ': 'http://www.health.ny.gov/prevention/obesity/statistics_and_impact/student_weight_status_data.htm',
#       'See Also': 'http://www.health.ny.gov/statistics/prevention/obesity/'},
#      'Dataset Information': {'Agency': 'Health, Department of'},
#      'Local Data': {'County Filter': 'Yes',
#       'County_Column': 'county',
#       'Municipality_Column': 'city',
#       'Municipality Filter': 'Yes'}},
#     'renderTypeConfig': {'visible': {'table': True}},
#     'availableDisplayTypes': ['table', 'fatrow', 'page'],
#     'jsonQuery': {'order': [{'ascending': False,
#        'columnFieldName': 'school_years'},
#       {'ascending': True, 'columnFieldName': 'location_code'},
#       {'ascending': True, 'columnFieldName': 'grade_category'}]},
#     'rdfSubject': '0',
#     'filterCondition': {'value': 'AND',
#      'children': [{'value': 'OR',
#        'type': 'operator',
#        'metadata': {'tableColumnId': {'742658': 8751876},
#         'operator': 'CONTAINS'}},
#       {'value': 'OR',
#        'type': 'operator',
#        'metadata': {'tableColumnId': {'742658': 8751874},
#         'operator': 'CONTAINS'}},
#       {'value': 'OR',
#        'type': 'operator',
#        'metadata': {'tableColumnId': {'742658': 8751875},
#         'operator': 'STARTS_WITH'}},
#       {'value': 'OR',
#        'type': 'operator',
#        'metadata': {'tableColumnId': {'742658': 8751885},
#         'operator': 'STARTS_WITH'}}],
#      'type': 'operator',
#      'metadata': {'unifiedVersion': 2, 'advanced': True}},
#     'attachments': [{'assetId': '',
#       'blobId': '4F5C54E2-8E27-4B2A-B441-24A61C784B0E',
#       'name': 'NYSDOH_StudentWeightResults_Overview.pdf',
#       'filename': 'NYSDOH_StudentWeightResults_Overview.pdf'},
#      {'assetId': '',
#       'blobId': '9BE4787B-6C9D-4E78-A6CB-23C363C68349',
#       'name': 'NYSDOH_StudentWeightResults_Benefits.pdf',
#       'filename': 'NYSDOH_StudentWeightResults_Benefits.pdf'},
#      {'assetId': '',
#       'blobId': '95B1CFA1-C330-4599-8672-1C51E29424D7',
#       'name': 'NYSDOH_StudentWeightResults_Data_Dictionary.pdf',
#       'filename': 'NYSDOH_StudentWeightResults_Data_Dictionary.pdf'},
#      {'assetId': '',
#       'blobId': 'BEF5D490-2815-4E55-9B12-B6781C13ECE3',
#       'name': 'NYSDOH_StudentWeightResults_ResearchQuestions.pdf',
#       'filename': 'NYSDOH_StudentWeightResults_ResearchQuestions.pdf'},
#      {'assetId': '',
#       'blobId': 'F0D959CD-450A-4ABD-850C-6E3384850782',
#       'name': 'NYSDOH_StudentWeightResults_SchoolandDistrictTallySheets.pdf',
#       'filename': 'NYSDOH_StudentWeightResults_SchoolandDistrictTallySheets.pdf'},
#      {'assetId': 'a3hz7-RYv_qQC_iIxQsVvUYxBfHSt90q4z_UijE3h7A',
#       'blobId': '',
#       'name': 'NYSDOH_SWSCR1012_Instructions_for_District_Visualizations_Final.docx',
#       'filename': 'NYSDOH_SWSCR1012_Instructions_for_District_Visualizations_Final.docx'}]},
#    'owner': {'id': 's9j2-nqmr',
#     'displayName': 'Open Data NY - DOH',
#     'profileImageUrlLarge': '/images/profile/2196/7719/DOHLogo_Blue_134x89_large.JPG',
#     'profileImageUrlMedium': '/images/profile/2196/7719/DOHLogo_Blue_134x89_thumb.JPG',
#     'profileImageUrlSmall': '/images/profile/2196/7719/DOHLogo_Blue_134x89_tiny.JPG',
#     'roleName': 'publisher',
#     'screenName': 'Open Data NY - DOH',
#     'rights': ['create_datasets',
#      'edit_others_datasets',
#      'edit_nominations',
#      'approve_nominations',
#      'moderate_comments',
#      'manage_stories',
#      'feature_items',
#      'change_configurations',
#      'view_domain',
#      'view_others_datasets',
#      'create_pages',
#      'edit_pages',
#      'view_goals',
#      'view_dashboards',
#      'edit_goals',
#      'edit_dashboards']},
#    'query': {'orderBys': [{'ascending': False,
#       'expression': {'columnId': 168098717, 'type': 'column'}},
#      {'ascending': True,
#       'expression': {'columnId': 168098713, 'type': 'column'}},
#      {'ascending': True,
#       'expression': {'columnId': 168098724, 'type': 'column'}}]},
#    'rights': ['read'],
#    'sortBys': [{'id': 0, 'viewColumnId': 168098717},
#     {'id': 0, 'viewColumnId': 168098713, 'flags': ['asc']},
#     {'id': 0, 'viewColumnId': 168098724, 'flags': ['asc']}],
#    'tableAuthor': {'id': 's9j2-nqmr',
#     'displayName': 'Open Data NY - DOH',
#     'profileImageUrlLarge': '/images/profile/2196/7719/DOHLogo_Blue_134x89_large.JPG',
#     'profileImageUrlMedium': '/images/profile/2196/7719/DOHLogo_Blue_134x89_thumb.JPG',
#     'profileImageUrlSmall': '/images/profile/2196/7719/DOHLogo_Blue_134x89_tiny.JPG',
#     'roleName': 'publisher',
#     'screenName': 'Open Data NY - DOH',
#     'rights': ['create_datasets',
#      'edit_others_datasets',
#      'edit_nominations',
#      'approve_nominations',
#      'moderate_comments',
#      'manage_stories',
#      'feature_items',
#      'change_configurations',
#      'view_domain',
#      'view_others_datasets',
#      'create_pages',
#      'edit_pages',
#      'view_goals',
#      'view_dashboards',
#      'edit_goals',
#      'edit_dashboards']},
#    'tags': ['bmi', 'chronic disease', 'childhood obesity', 'swscr'],
#    'flags': ['default']}},
#  'data': [[2237,
#    '5273C009-D32B-4885-B20E-136767936ADD',
#    2237,
#    1411498109,
#    '698552',
#    1411498125,
#    '705890',
#    '{\n}',
#    '010402',
#    'ALBANY',
#    'RAVENA COEYMANS SELKIRK CENTRAL SCHOOL DISTRICT',
#    'NORTHEASTERN NEW YORK',
#    '2012-2013',
#    '124',
#    '18.5',
#    '139',
#    '20.8',
#    '263',
#    '39.3',
#    'DISTRICT TOTAL',
#    'SCHOOL DISTRICT',
#    '15 MOUNTAIN RD',
#    'RAVENA',
#    'NY',
#    '12143',
#    ['{"address":"15 MOUNTAIN RD","city":"RAVENA","state":"NY","zip":"12143"}',
#     '42.47227638700048',
#     '-73.81484141099963',
#     None,
#     False]],
#   [2238,
#    'B5CF19C8-512B-4763-80AB-0CC83E62A5F4',
#    2238,
#    1411498109,
#    '698552',
#    1411498137,
#    '705890',
#    '{\n}',
#    '010402',
#    'ALBANY',
#    'RAVENA COEYMANS SELKIRK CENTRAL SCHOOL DISTRICT',
#    'NORTHEASTERN NEW YORK',
#    '2012-2013',
#    '74',
#    '19.2',
#    '72',
#    '18.7',
#    '146',
#    '37.9',
#    'ELEMENTARY',
#    'SCHOOL DISTRICT',
#    '15 MOUNTAIN RD',
#    'RAVENA',
#    'NY',
#    '12143',
#    ['{"address":"15 MOUNTAIN RD","city":"RAVENA","state":"NY","zip":"12143"}',
#     '42.47227638700048',
#     '-73.81484141099963',
#     None,
#     False]],
#   [2239,
#    'E4A091E8-1061-487D-A719-D3892621870C',
#    2239,
#    1411498109,
#    '698552',
#    1411498141,
#    '705890',
#    '{\n}',
#    '010402',
#    'ALBANY',
#    'RAVENA COEYMANS SELKIRK CENTRAL SCHOOL DISTRICT',
#    'NORTHEASTERN NEW YORK',
#    '2012-2013',
#    '50',
#    '17.6',
#    '67',
#    '23.6',
#    '117',
#    '41.2',
#    'MIDDLE/HIGH',
#    'SCHOOL DISTRICT',
#    '15 MOUNTAIN RD',
#    'RAVENA',
#    'NY',
#    '12143',
#    ['{"address":"15 MOUNTAIN RD","city":"RAVENA","state":"NY","zip":"12143"}',
#     '42.47227638700048',
#     '-73.81484141099963',
#     None,
#     False]],
#   [2240,
#    'C873D7C8-3028-4DB6-B0A8-5FA6EC2B58C1',
#    2240,
#    1411498109,
#    '698552',
#    1411498138,
#    '705890',
#    '{\n}',
#    '010500',
#    'ALBANY',
#    'COHOES CITY SCHOOL DISTRICT',
#    'NORTHEASTERN NEW YORK',
#    '2012-2013',
#    '84',
#    '17.2',
#    '124',
#    '25.4',
#    '208',
#    '42.5',
#    'DISTRICT TOTAL',
#    'SCHOOL DISTRICT',
#    '7 BEVAN ST',
#    'COHOES',
#    'NY',
#    '12047',
#    ['{"address":"7 BEVAN ST","city":"COHOES","state":"NY","zip":"12047"}',
#     '42.771285452000484',
#     '-73.71046311499964',
#     None,
#     False]],
#   [2241,
#    '16B84D67-1B96-4B1C-8756-54A26B8FB3B8',
#    2241,
#    1411498109,
#    '698552',
#    1411498119,
#    '705890',
#    '{\n}',
#    '010500',
#    'ALBANY',
#    'COHOES CITY SCHOOL DISTRICT',
#    'NORTHEASTERN NEW YORK',
#    '2012-2013',
#    '58',
#    '16.1',
#    '89',
#    '24.7',
#    '147',
#    '40.8',
#    'ELEMENTARY',
#    'SCHOOL DISTRICT',
#    '7 BEVAN ST',
#    'COHOES',
#    'NY',
#    '12047',
#    ['{"address":"7 BEVAN ST","city":"COHOES","state":"NY","zip":"12047"}',
#     '42.771285452000484',
#     '-73.71046311499964',
#     None,
#     False]],
#   [2242,
#    '60BE9A2F-4B9D-4D76-992D-CA04DF397574',
#    2242,
#    1411498109,
#    '698552',
#    1411498127,
#    '705890',
#    '{\n}',
#    '010500',
#    'ALBANY',
#    'COHOES CITY SCHOOL DISTRICT',
#    'NORTHEASTERN NEW YORK',
#    '2012-2013',
#    '26',
#    '20.2',
#    '35',
#    '27.1',
#    '61',
#    '47.3',
#    'MIDDLE/HIGH',
#    'SCHOOL DISTRICT',
#    '7 BEVAN ST',
#    'COHOES',
#    'NY',
#    '12047',
#    ['{"address":"7 BEVAN ST","city":"COHOES","state":"NY","zip":"12047"}',
#     '42.771285452000484',
#     '-73.71046311499964',
#     None,
#     False]],
#   [2243,
#    '69971C3F-9F05-496A-A248-5FFEABEA4962',
#    2243,
#    1411498109,
#    '698552',
#    1411498128,
#    '705890',
#    '{\n}',
#    '010601',
#    'ALBANY',
#    'SOUTH COLONIE CENTRAL SCHOOL DISTRICT',
#    'NORTHEASTERN NEW YORK',
#    '2012-2013',
#    '231',
#    '15.9',
#    '262',
#    '18.1',
#    '493',
#    '34.0',
#    'DISTRICT TOTAL',
#    'SCHOOL DISTRICT',
#    '102 LORALEE DR',
#    'ALBANY',
#    'NY',
#    '12205',
#    ['{"address":"102 LORALEE DR","city":"ALBANY","state":"NY","zip":"12205"}',
#     '42.73352407800047',
#     '-73.84142054399967',
#     None,
#     False]],
#   [2244,
#    '9457A212-9E9A-45B0-9DF6-8A45BCEF8DF7',
#    2244,
#    1411498109,
#    '698552',
#    1411498137,
#    '705890',
#    '{\n}',
#    '010601',
#    'ALBANY',
#    'SOUTH COLONIE CENTRAL SCHOOL DISTRICT',
#    'NORTHEASTERN NEW YORK',
#    '2012-2013',
#    '145',
#    '17.4',
#    '169',
#    '20.3',
#    '314',
#    '37.8',
#    'ELEMENTARY',
#    'SCHOOL DISTRICT',
#    '102 LORALEE DR',
#    'ALBANY',
#    'NY',
#    '12205',
#    ['{"address":"102 LORALEE DR","city":"ALBANY","state":"NY","zip":"12205"}',
#     '42.73352407800047',
#     '-73.84142054399967',
#     None,
#     False]],
#   [2245,
#    'BC07FEC6-DD99-41D5-8A19-2B7ABE650CA7',
#    2245,
#    1411498109,
#    '698552',
#    1411498138,
#    '705890',
#    '{\n}',
#    '010601',
#    'ALBANY',
#    'SOUTH COLONIE CENTRAL SCHOOL DISTRICT',
#    'NORTHEASTERN NEW YORK',
#    '2012-2013',
#    '86',
#    '13.9',
#    '95',
#    '15.3',
#    '181',
#    '29.2',
#    'MIDDLE/HIGH',
#    'SCHOOL DISTRICT',
#    '102 LORALEE DR',
#    'ALBANY',
#    'NY',
#    '12205',
#    ['{"address":"102 LORALEE DR","city":"ALBANY","state":"NY","zip":"12205"}',
#     '42.73352407800047',
#     '-73.84142054399967',
#     None,
#     False]],
#   [2246,
#    '5197E99D-F534-4C36-A1AF-F5ACDB05418F',
#    2246,
#    1411498109,
#    '698552',
#    1411498125,
#    '705890',
#    '{\n}',
#    '010623',
#    'ALBANY',
#    'NORTH COLONIE CENTRAL SCHOOL DISTRICT',
#    'NORTHEASTERN NEW YORK',
#    '2012-2013',
#    '237',
#    '16.3',
#    '225',
#    '15.5',
#    '462',
#    '31.8',
#    'DISTRICT TOTAL',
#    'SCHOOL DISTRICT',
#    '91 FIDDLERS LN',
#    'LATHAM',
#    'NY',
#    '12110',
#    ['{"address":"91 FIDDLERS LN","city":"LATHAM","state":"NY","zip":"12110"}',
#     '42.72935391700048',
#     '-73.74701579899966',
#     None,
#     False]],
#   [2247,
#    'A59CCF34-ABAB-44CB-8A22-76300F3AEC06',
#    2247,
#    1411498109,
#    '698552',
#    1411498137,
#    '705890',
#    '{\n}',
#    '010623',
#    'ALBANY',
#    'NORTH COLONIE CENTRAL SCHOOL DISTRICT',
#    'NORTHEASTERN NEW YORK',
#    '2012-2013',
#    '94',
#    '15.5',
#    '78',
#    '12.9',
#    '172',
#    '28.4',
#    'ELEMENTARY',
#    'SCHOOL DISTRICT',
#    '91 FIDDLERS LN',
#    'LATHAM',
#    'NY',
#    '12110',
#    ['{"address":"91 FIDDLERS LN","city":"LATHAM","state":"NY","zip":"12110"}',
#     '42.72935391700048',
#     '-73.74701579899966',
#     None,
#     False]],
#   [2248,
#    'B8148D9D-D59B-4ADB-9FD5-588CE845C8D1',
#    2248,
#    1411498109,
#    '698552',
#    1411498138,
#    '705890',
#    '{\n}',
#    '010623',
#    'ALBANY',
#    'NORTH COLONIE CENTRAL SCHOOL DISTRICT',
#    'NORTHEASTERN NEW YORK',
#    '2012-2013',
#    '143',
#    '16.9',
#    '147',
#    '17.3',
#    '290',
#    '34.2',
#    'MIDDLE/HIGH',
#    'SCHOOL DISTRICT',
#    '91 FIDDLERS LN',
#    'LATHAM',
#    'NY',
#    '12110',
#    ['{"address":"91 FIDDLERS LN","city":"LATHAM","state":"NY","zip":"12110"}',
#     '42.72935391700048',
#     '-73.74701579899966',
#     None,
#     False]],
#   [2249,
#    '1F8D9A59-655D-4053-B6C2-57743F68F595',
#    2249,
#    1411498109,
#    '698552',
#    1411498119,
#    '705890',
#    '{\n}',
#    '010701',
#    'ALBANY',
#    'GREEN ISLAND UNION FREE SCHOOL DISTRICT',
#    'NORTHEASTERN NEW YORK',
#    '2012-2013',
#    '12',
#    '17.6',
#    '19',
#    '27.9',
#    '31',
#    '45.6',
#    'DISTRICT TOTAL',
#    'SCHOOL DISTRICT',
#    '171 HUDSON AVE',
#    'GREEN ISLAND',
#    'NY',
#    '12183',
#    ['{"address":"171 HUDSON AVE","city":"GREEN ISLAND","state":"NY","zip":"12183"}',
#     '42.74619105800048',
#     '-73.69017488899965',
#     None,
#     False]],
#   [2250,
#    'B9FEF941-6376-44C6-AF21-E30F454DF14E',
#    2250,
#    1411498109,
#    '698552',
#    1411498138,
#    '705890',
#    '{\n}',
#    '010701',
#    'ALBANY',
#    'GREEN ISLAND UNION FREE SCHOOL DISTRICT',
#    'NORTHEASTERN NEW YORK',
#    '2012-2013',
#    None,
#    None,
#    '15',
#    '35.7',
#    '15',
#    '35.7',
#    'ELEMENTARY',
#    'SCHOOL DISTRICT',
#    '171 HUDSON AVE',
#    'GREEN ISLAND',
#    'NY',
#    '12183',
#    ['{"address":"171 HUDSON AVE","city":"GREEN ISLAND","state":"NY","zip":"12183"}',
#     '42.74619105800048',
#     '-73.69017488899965',
#     None,
#     False]],
#   [2251,
#    '711C9EFD-1A33-41FB-B8FE-66159A97F968',
#    2251,
#    1411498109,
#    '698552',
#    1411498132,
#    '705890',
#    '{\n}',
#    '010701',
#    'ALBANY',
#    'GREEN ISLAND UNION FREE SCHOOL DISTRICT',
#    'NORTHEASTERN NEW YORK',
#    '2012-2013',
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    'MIDDLE/HIGH',
#    'SCHOOL DISTRICT',
#    '171 HUDSON AVE',
#    'GREEN ISLAND',
#    'NY',
#    '12183',
#    ['{"address":"171 HUDSON AVE","city":"GREEN ISLAND","state":"NY","zip":"12183"}',
#     '42.74619105800048',
#     '-73.69017488899965',
#     None,
#     False]],
#   [2252,
#    '8D017BA3-D099-4177-94C6-3FE680A73917',
#    2252,
#    1411498109,
#    '698552',
#    1411498136,
#    '705890',
#    '{\n}',
#    '010802',
#    'ALBANY',
#    'GUILDERLAND CENTRAL SCHOOL DISTRICT',
#    'NORTHEASTERN NEW YORK',
#    '2012-2013',
#    '192',
#    '13.0',
#    '193',
#    '13.1',
#    '385',
#    '26.1',
#    'DISTRICT TOTAL',
#    'SCHOOL DISTRICT',
#    '8 SCHOOL RD',
#    'GUILDERLAND CENTER',
#    'NY',
#    '12085',
#    ['{"address":"8 SCHOOL RD","city":"GUILDERLAND CENTER","state":"NY","zip":"12085"}',
#     '42.70288977200045',
#     '-73.96575979499966',
#     None,
#     False]],
#   [2253,
#    '1F44EB8A-9AD8-4ADE-A4DF-ECEFC5704440',
#    2253,
#    1411498109,
#    '698552',
#    1411498119,
#    '705890',
#    '{\n}',
#    '010802',
#    'ALBANY',
#    'GUILDERLAND CENTRAL SCHOOL DISTRICT',
#    'NORTHEASTERN NEW YORK',
#    '2012-2013',
#    '103',
#    '12.6',
#    '113',
#    '13.8',
#    '216',
#    '26.4',
#    'ELEMENTARY',
#    'SCHOOL DISTRICT',
#    '8 SCHOOL RD',
#    'GUILDERLAND CENTER',
#    'NY',
#    '12085',
#    ['{"address":"8 SCHOOL RD","city":"GUILDERLAND CENTER","state":"NY","zip":"12085"}',
#     '42.70288977200045',
#     '-73.96575979499966',
#     None,
#     False]],
#   [2254,
#    '6C20E570-CC9B-43C9-8ADB-EAEB16B3F2E4',
#    2254,
#    1411498109,
#    '698552',
#    1411498129,
#    '705890',
#    '{\n}',
#    '010802',
#    'ALBANY',
#    'GUILDERLAND CENTRAL SCHOOL DISTRICT',
#    'NORTHEASTERN NEW YORK',
#    '2012-2013',
#    '89',
#    '13.6',
#    '80',
#    '12.2',
#    '169',
#    '25.8',
#    'MIDDLE/HIGH',
#    'SCHOOL DISTRICT',
#    '8 SCHOOL RD',
#    'GUILDERLAND CENTER',
#    'NY',
#    '12085',
#    ['{"address":"8 SCHOOL RD","city":"GUILDERLAND CENTER","state":"NY","zip":"12085"}',
#     '42.70288977200045',
#     '-73.96575979499966',
#     None,
#     False]],
#   [2255,
#    'BC8579C9-CE52-444A-9CD2-0B2975CB4692',
#    2255,
#    1411498109,
#    '698552',
#    1411498138,
#    '705890',
#    '{\n}',
#    '020101',
#    'ALLEGANY',
#    'ALFRED ALMOND CENTRAL SCHOOL DISTRICT',
#    'WESTERN NEW YORK',
#    '2012-2013',
#    '35',
#    '21.1',
#    '25',
#    '15.1',
#    '60',
#    '36.1',
#    'DISTRICT TOTAL',
#    'SCHOOL DISTRICT',
#    '6795 RT 21',
#    'ALMOND',
#    'NY',
#    '14804',
#    ['{"address":"6795 RT 21","city":"ALMOND","state":"NY","zip":"14804"}',
#     '42.295582036000496',
#     '-77.74865778099968',
#     None,
#     False]],
#   [2256,
#    'FA7DD7D4-40B6-4A4F-AC92-EB634A0522D8',
#    2256,
#    1411498109,
#    '698552',
#    1411498146,
#    '705890',
#    '{\n}',
#    '020101',
#    'ALLEGANY',
#    'ALFRED ALMOND CENTRAL SCHOOL DISTRICT',
#    'WESTERN NEW YORK',
#    '2012-2013',
#    '21',
#    '21.9',
#    '9',
#    '9.4',
#    '30',
#    '31.3',
#    'ELEMENTARY',
#    'SCHOOL DISTRICT',
#    '6795 RT 21',
#    'ALMOND',
#    'NY',
#    '14804',
#    ['{"address":"6795 RT 21","city":"ALMOND","state":"NY","zip":"14804"}',
#     '42.295582036000496',
#     '-77.74865778099968',
#     None,
#     False]],
#   [2257,
#    'BFF22DC2-B996-4B70-8CB4-5C8687DE9742',
#    2257,
#    1411498109,
#    '698552',
#    1411498138,
#    '705890',
#    '{\n}',
#    '020101',
#    'ALLEGANY',
#    'ALFRED ALMOND CENTRAL SCHOOL DISTRICT',
#    'WESTERN NEW YORK',
#    '2012-2013',
#    '14',
#    '20.9',
#    '13',
#    '19.4',
#    '27',
#    '40.3',
#    'MIDDLE/HIGH',
#    'SCHOOL DISTRICT',
#    '6795 RT 21',
#    'ALMOND',
#    'NY',
#    '14804',
#    ['{"address":"6795 RT 21","city":"ALMOND","state":"NY","zip":"14804"}',
#     '42.295582036000496',
#     '-77.74865778099968',
#     None,
#     False]],
#   [2258,
#    'FF36F9F0-9D6F-444C-976E-DFD54B35CF81',
#    2258,
#    1411498109,
#    '698552',
#    1411498146,
#    '705890',
#    '{\n}',
#    '021102',
#    'ALLEGANY',
#    'CANASERAGA CENTRAL SCHOOL DISTRICT',
#    'WESTERN NEW YORK',
#    '2012-2013',
#    '7',
#    '14.3',
#    '15',
#    '30.6',
#    '22',
#    '44.9',
#    'DISTRICT TOTAL',
#    'SCHOOL DISTRICT',
#    '4-8 MAIN ST',
#    'CANASERAGA',
#    'NY',
#    '14822',
#    ['{"address":"4-8 MAIN ST","city":"CANASERAGA","state":"NY","zip":"14822"}',
#     '42.46130666300047',
#     '-77.77724128399967',
#     None,
#     False]],
#   [2259,
#    'DE2F0BB6-8EBC-4B57-818E-8A8948A61F2B',
#    2259,
#    1411498109,
#    '698552',
#    1411498141,
#    '705890',
#    '{\n}',
#    '021102',
#    'ALLEGANY',
#    'CANASERAGA CENTRAL SCHOOL DISTRICT',
#    'WESTERN NEW YORK',
#    '2012-2013',
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    'ELEMENTARY',
#    'SCHOOL DISTRICT',
#    '4-8 MAIN ST',
#    'CANASERAGA',
#    'NY',
#    '14822',
#    ['{"address":"4-8 MAIN ST","city":"CANASERAGA","state":"NY","zip":"14822"}',
#     '42.46130666300047',
#     '-77.77724128399967',
#     None,
#     False]],
#   [2260,
#    'B14173DB-A71C-4EC1-BB80-1B3E31AF3C17',
#    2260,
#    1411498109,
#    '698552',
#    1411498137,
#    '705890',
#    '{\n}',
#    '021102',
#    'ALLEGANY',
#    'CANASERAGA CENTRAL SCHOOL DISTRICT',
#    'WESTERN NEW YORK',
#    '2012-2013',
#    None,
#    None,
#    '5',
#    '38.5',
#    '5',
#    '38.5',
#    'MIDDLE/HIGH',
#    'SCHOOL DISTRICT',
#    '4-8 MAIN ST',
#    'CANASERAGA',
#    'NY',
#    '14822',
#    ['{"address":"4-8 MAIN ST","city":"CANASERAGA","state":"NY","zip":"14822"}',
#     '42.46130666300047',
#     '-77.77724128399967',
#     None,
#     False]],
#   [2261,
#    '5DB235CF-1DE3-4409-BD8E-2FE843D807F8',
#    2261,
#    1411498109,
#    '698552',
#    1411498127,
#    '705890',
#    '{\n}',
#    '021601',
#    'ALLEGANY',
#    'FRIENDSHIP CENTRAL SCHOOL DISTRICT',
#    'WESTERN NEW YORK',
#    '2012-2013',
#    '27',
#    '17.5',
#    '29',
#    '18.8',
#    '56',
#    '36.4',
# ...
#     '41.251565163000464',
#     '-73.93806758099964',
#     None,
#     False]],
#   [3208,
#    'AE109E5A-AB47-4B76-9926-263488E29E29',
#    3208,
#    1411498111,
#    '698552',
#    1411498137,
#    '705890',
#    '{\n}',
#    '660203',
#    'WESTCHESTER',
#    'HENDRICK HUDSON CENTRAL SCHOOL',
#    'HUDSON VALLEY',
#    '2012-2013',
#    '55',
#    '14.6',
#    '56',
#    '14.9',
#    '111',
#    '29.4',
#    'MIDDLE/HIGH',
#    'SCHOOL DISTRICT',
#    '61 TROLLEY RD',
#    'MONTROSE',
#    'NY',
#    '10548',
#    ['{"address":"61 TROLLEY RD","city":"MONTROSE","state":"NY","zip":"10548"}',
#     '41.251565163000464',
#     '-73.93806758099964',
#     None,
#     False]],
#   [3209,
#    'C1EFD379-A50B-4C2E-8694-D4827447D17F',
#    3209,
#    1411498111,
#    '698552',
#    1411498138,
#    '705890',
#    '{\n}',
#    '660303',
#    'WESTCHESTER',
#    'BRONXVILLE UNION FREE SCHOOL',
#    'HUDSON VALLEY',
#    '2012-2013',
#    '54',
#    '11.0',
#    '28',
#    '5.7',
#    '82',
#    '16.6',
#    'DISTRICT TOTAL',
#    'SCHOOL DISTRICT',
#    '177 PONDFIELD RD',
#    'BRONXVILLE',
#    'NY',
#    '10708',
#    ['{"address":"177 PONDFIELD RD","city":"BRONXVILLE","state":"NY","zip":"10708"}',
#     '40.93692391200045',
#     '-73.83159541999964',
#     None,
#     False]],
#   [3210,
#    'E8DAFA9C-EFA0-4AB4-97DF-6DBD07F8035F',
#    3210,
#    1411498111,
#    '698552',
#    1411498141,
#    '705890',
#    '{\n}',
#    '660303',
#    'WESTCHESTER',
#    'BRONXVILLE UNION FREE SCHOOL',
#    'HUDSON VALLEY',
#    '2012-2013',
#    '30',
#    '10.1',
#    '16',
#    '5.4',
#    '46',
#    '15.5',
#    'ELEMENTARY',
#    'SCHOOL DISTRICT',
#    '177 PONDFIELD RD',
#    'BRONXVILLE',
#    'NY',
#    '10708',
#    ['{"address":"177 PONDFIELD RD","city":"BRONXVILLE","state":"NY","zip":"10708"}',
#     '40.93692391200045',
#     '-73.83159541999964',
#     None,
#     False]],
#   [3211,
#    'E17DACCF-53C0-47A5-AE8F-94341580AC42',
#    3211,
#    1411498111,
#    '698552',
#    1411498141,
#    '705890',
#    '{\n}',
#    '660303',
#    'WESTCHESTER',
#    'BRONXVILLE UNION FREE SCHOOL',
#    'HUDSON VALLEY',
#    '2012-2013',
#    '24',
#    '12.2',
#    '12',
#    '6.1',
#    '36',
#    '18.3',
#    'MIDDLE/HIGH',
#    'SCHOOL DISTRICT',
#    '177 PONDFIELD RD',
#    'BRONXVILLE',
#    'NY',
#    '10708',
#    ['{"address":"177 PONDFIELD RD","city":"BRONXVILLE","state":"NY","zip":"10708"}',
#     '40.93692391200045',
#     '-73.83159541999964',
#     None,
#     False]],
#   [3212,
#    '85F287AA-8F84-4E44-8603-6B8D57DE3C1C',
#    3212,
#    1411498111,
#    '698552',
#    1411498136,
#    '705890',
#    '{\n}',
#    '660402',
#    'WESTCHESTER',
#    'IRVINGTON UNION FREE SCHOOL',
#    'HUDSON VALLEY',
#    '2012-2013',
#    '70',
#    '12.9',
#    '36',
#    '6.6',
#    '106',
#    '19.5',
#    'DISTRICT TOTAL',
#    'SCHOOL DISTRICT',
#    '6 DOWS LN',
#    'IRVINGTON',
#    'NY',
#    '10533',
#    ['{"address":"6 DOWS LN","city":"IRVINGTON","state":"NY","zip":"10533"}',
#     '41.034281500000475',
#     '-73.87078616199966',
#     None,
#     False]],
#   [3213,
#    '7DB76E1F-0AE0-44E8-AD58-3D89FCE4124E',
#    3213,
#    1411498111,
#    '698552',
#    1411498136,
#    '705890',
#    '{\n}',
#    '660402',
#    'WESTCHESTER',
#    'IRVINGTON UNION FREE SCHOOL',
#    'HUDSON VALLEY',
#    '2012-2013',
#    '37',
#    '12.2',
#    '13',
#    '4.3',
#    '50',
#    '16.4',
#    'ELEMENTARY',
#    'SCHOOL DISTRICT',
#    '6 DOWS LN',
#    'IRVINGTON',
#    'NY',
#    '10533',
#    ['{"address":"6 DOWS LN","city":"IRVINGTON","state":"NY","zip":"10533"}',
#     '41.034281500000475',
#     '-73.87078616199966',
#     None,
#     False]],
#   [3214,
#    '037E87C7-5A55-42C5-949A-142D5B929F9A',
#    3214,
#    1411498111,
#    '698552',
#    1411498118,
#    '705890',
#    '{\n}',
#    '660402',
#    'WESTCHESTER',
#    'IRVINGTON UNION FREE SCHOOL',
#    'HUDSON VALLEY',
#    '2012-2013',
#    '33',
#    '14.2',
#    '23',
#    '9.9',
#    '56',
#    '24.1',
#    'MIDDLE/HIGH',
#    'SCHOOL DISTRICT',
#    '6 DOWS LN',
#    'IRVINGTON',
#    'NY',
#    '10533',
#    ['{"address":"6 DOWS LN","city":"IRVINGTON","state":"NY","zip":"10533"}',
#     '41.034281500000475',
#     '-73.87078616199966',
#     None,
#     False]],
#   [3215,
#    '9AD6FAA2-5874-451C-85C7-76EA5BE12EEA',
#    3215,
#    1411498111,
#    '698552',
#    1411498137,
#    '705890',
#    '{\n}',
#    '660403',
#    'WESTCHESTER',
#    'DOBBS FERRY UNION FREE SCHOOL',
#    'HUDSON VALLEY',
#    '2012-2013',
#    '40',
#    '10.6',
#    '41',
#    '10.8',
#    '81',
#    '21.4',
#    'DISTRICT TOTAL',
#    'SCHOOL DISTRICT',
#    '505 BROADWAY',
#    'DOBBS FERRY',
#    'NY',
#    '10522',
#    ['{"address":"505 BROADWAY","city":"DOBBS FERRY","state":"NY","zip":"10522"}',
#     '41.01839851300048',
#     '-73.86956593399964',
#     None,
#     False]],
#   [3216,
#    'B65ED617-7283-454A-8AF7-DD9F622B6514',
#    3216,
#    1411498111,
#    '698552',
#    1411498137,
#    '705890',
#    '{\n}',
#    '660403',
#    'WESTCHESTER',
#    'DOBBS FERRY UNION FREE SCHOOL',
#    'HUDSON VALLEY',
#    '2012-2013',
#    '26',
#    '11.0',
#    '24',
#    '10.1',
#    '50',
#    '21.1',
#    'ELEMENTARY',
#    'SCHOOL DISTRICT',
#    '505 BROADWAY',
#    'DOBBS FERRY',
#    'NY',
#    '10522',
#    ['{"address":"505 BROADWAY","city":"DOBBS FERRY","state":"NY","zip":"10522"}',
#     '41.01839851300048',
#     '-73.86956593399964',
#     None,
#     False]],
#   [3217,
#    'B3F03F91-5212-4D27-9E7C-0DB47F550E8E',
#    3217,
#    1411498111,
#    '698552',
#    1411498137,
#    '705890',
#    '{\n}',
#    '660403',
#    'WESTCHESTER',
#    'DOBBS FERRY UNION FREE SCHOOL',
#    'HUDSON VALLEY',
#    '2012-2013',
#    '14',
#    '10.0',
#    '17',
#    '12.1',
#    '31',
#    '22.1',
#    'MIDDLE/HIGH',
#    'SCHOOL DISTRICT',
#    '505 BROADWAY',
#    'DOBBS FERRY',
#    'NY',
#    '10522',
#    ['{"address":"505 BROADWAY","city":"DOBBS FERRY","state":"NY","zip":"10522"}',
#     '41.01839851300048',
#     '-73.86956593399964',
#     None,
#     False]],
#   [3218,
#    'D4F62896-EF94-42B0-B173-A39EE78089BB',
#    3218,
#    1411498111,
#    '698552',
#    1411498138,
#    '705890',
#    '{\n}',
#    '660404',
#    'WESTCHESTER',
#    'HASTINGS ON HUDSON U F S',
#    'HUDSON VALLEY',
#    '2012-2013',
#    '65',
#    '12.5',
#    '35',
#    '6.7',
#    '100',
#    '19.2',
#    'DISTRICT TOTAL',
#    'SCHOOL DISTRICT',
#    '27 FARRAGUT AVE',
#    'HASTINGS ON HUDSON',
#    'NY',
#    '10706',
#    ['{"address":"27 FARRAGUT AVE","city":"HASTINGS ON HUDSON","state":"NY","zip":"10706"}',
#     '40.993994177000445',
#     '-73.87715568199962',
#     None,
#     False]],
#   [3219,
#    '0987CD73-29B4-4A37-B0D1-B9A00DE56B0E',
#    3219,
#    1411498111,
#    '698552',
#    1411498118,
#    '705890',
#    '{\n}',
#    '660404',
#    'WESTCHESTER',
#    'HASTINGS ON HUDSON U F S',
#    'HUDSON VALLEY',
#    '2012-2013',
#    '39',
#    '13.7',
#    '14',
#    '4.9',
#    '53',
#    '18.7',
#    'ELEMENTARY',
#    'SCHOOL DISTRICT',
#    '27 FARRAGUT AVE',
#    'HASTINGS ON HUDSON',
#    'NY',
#    '10706',
#    ['{"address":"27 FARRAGUT AVE","city":"HASTINGS ON HUDSON","state":"NY","zip":"10706"}',
#     '40.993994177000445',
#     '-73.87715568199962',
#     None,
#     False]],
#   [3220,
#    '15935927-439C-40AA-B62D-C074E24C5AC6',
#    3220,
#    1411498111,
#    '698552',
#    1411498119,
#    '705890',
#    '{\n}',
#    '660404',
#    'WESTCHESTER',
#    'HASTINGS ON HUDSON U F S',
#    'HUDSON VALLEY',
#    '2012-2013',
#    '26',
#    '10.7',
#    '21',
#    '8.6',
#    '47',
#    '19.3',
#    'MIDDLE/HIGH',
#    'SCHOOL DISTRICT',
#    '27 FARRAGUT AVE',
#    'HASTINGS ON HUDSON',
#    'NY',
#    '10706',
#    ['{"address":"27 FARRAGUT AVE","city":"HASTINGS ON HUDSON","state":"NY","zip":"10706"}',
#     '40.993994177000445',
#     '-73.87715568199962',
#     None,
#     False]],
#   [3221,
#    '22A852B0-242E-4355-B6D8-FFC7050F8D18',
#    3221,
#    1411498111,
#    '698552',
#    1411498119,
#    '705890',
#    '{\n}',
#    '660405',
#    'WESTCHESTER',
#    'ARDSLEY UNION FREE SCHOOL',
#    'HUDSON VALLEY',
#    '2012-2013',
#    '86',
#    '13.3',
#    '80',
#    '12.4',
#    '166',
#    '25.7',
#    'DISTRICT TOTAL',
#    'SCHOOL DISTRICT',
#    '500 FARM RD',
#    'ARDSLEY',
#    'NY',
#    '10502',
#    ['{"address":"500 FARM RD","city":"ARDSLEY","state":"NY","zip":"10502"}',
#     '41.019600366000475',
#     '-73.83386611599963',
#     None,
#     False]],
#   [3222,
#    'FD145BDC-A940-45AC-AAF9-D806692FD35B',
#    3222,
#    1411498111,
#    '698552',
#    1411498146,
#    '705890',
#    '{\n}',
#    '660405',
#    'WESTCHESTER',
#    'ARDSLEY UNION FREE SCHOOL',
#    'HUDSON VALLEY',
#    '2012-2013',
#    '52',
#    '12.9',
#    '53',
#    '13.1',
#    '105',
#    '26.0',
#    'ELEMENTARY',
#    'SCHOOL DISTRICT',
#    '500 FARM RD',
#    'ARDSLEY',
#    'NY',
#    '10502',
#    ['{"address":"500 FARM RD","city":"ARDSLEY","state":"NY","zip":"10502"}',
#     '41.019600366000475',
#     '-73.83386611599963',
#     None,
#     False]],
#   [3223,
#    '4E4F69D6-0600-410A-8C6F-E09127C403AD',
#    3223,
#    1411498111,
#    '698552',
#    1411498124,
#    '705890',
#    '{\n}',
#    '660405',
#    'WESTCHESTER',
#    'ARDSLEY UNION FREE SCHOOL',
#    'HUDSON VALLEY',
#    '2012-2013',
#    '34',
#    '14.5',
#    '27',
#    '11.5',
#    '61',
#    '26.0',
#    'MIDDLE/HIGH',
#    'SCHOOL DISTRICT',
#    '500 FARM RD',
#    'ARDSLEY',
#    'NY',
#    '10502',
#    ['{"address":"500 FARM RD","city":"ARDSLEY","state":"NY","zip":"10502"}',
#     '41.019600366000475',
#     '-73.83386611599963',
#     None,
#     False]],
#   [3224,
#    '0B7EA78E-8346-4C15-8E1F-E998871F73FD',
#    3224,
#    1411498111,
#    '698552',
#    1411498119,
#    '705890',
#    '{\n}',
#    '660407',
#    'WESTCHESTER',
#    'GREENBURGH CENTRAL SCHOOL',
#    'HUDSON VALLEY',
#    '2012-2013',
#    '86',
#    '16.6',
#    '124',
#    '23.9',
#    '210',
#    '40.5',
#    'DISTRICT TOTAL',
#    'SCHOOL DISTRICT',
#    '475 W HARTSDALE AVE-ADMIN BLDG',
#    'HARTSDALE',
#    'NY',
#    '10530',
#    ['{"address":"475 W HARTSDALE AVE-ADMIN BLDG","city":"HARTSDALE","state":"NY","zip":"10530"}',
#     '41.03136647800045',
#     '-73.80889775999964',
#     None,
#     False]],
#   [3225,
#    'C4F5BD90-1209-45A4-8DFF-74E8174E807F',
#    3225,
#    1411498111,
#    '698552',
#    1411498138,
#    '705890',
#    '{\n}',
#    '660407',
#    'WESTCHESTER',
#    'GREENBURGH CENTRAL SCHOOL',
#    'HUDSON VALLEY',
#    '2012-2013',
#    '62',
#    '14.4',
#    '93',
#    '21.6',
#    '155',
#    '36.0',
#    'ELEMENTARY',
#    'SCHOOL DISTRICT',
#    '475 W HARTSDALE AVE-ADMIN BLDG',
#    'HARTSDALE',
#    'NY',
#    '10530',
#    ['{"address":"475 W HARTSDALE AVE-ADMIN BLDG","city":"HARTSDALE","state":"NY","zip":"10530"}',
#     '41.03136647800045',
#     '-73.80889775999964',
#     None,
#     False]],
#   [3226,
#    'F0E4697A-E8C8-4DE4-AF3F-2C15F824A4CE',
#    3226,
#    1411498111,
#    '698552',
#    1411498141,
#    '705890',
#    '{\n}',
#    '660407',
#    'WESTCHESTER',
#    'GREENBURGH CENTRAL SCHOOL',
#    'HUDSON VALLEY',
#    '2012-2013',
#    '19',
#    '20.4',
#    '31',
#    '33.3',
#    '50',
#    '53.8',
#    'MIDDLE/HIGH',
#    'SCHOOL DISTRICT',
#    '475 W HARTSDALE AVE-ADMIN BLDG',
#    'HARTSDALE',
#    'NY',
#    '10530',
#    ['{"address":"475 W HARTSDALE AVE-ADMIN BLDG","city":"HARTSDALE","state":"NY","zip":"10530"}',
#     '41.03136647800045',
#     '-73.80889775999964',
#     None,
#     False]],
#   [3227,
#    '6A121D21-5521-4CF1-916C-3652B19A8762',
#    3227,
#    1411498111,
#    '698552',
#    1411498128,
#    '705890',
#    '{\n}',
#    '660501',
#    'WESTCHESTER',
#    'HARRISON CENTRAL SCHOOL',
#    'HUDSON VALLEY',
#    '2012-2013',
#    '130',
#    '12.7',
#    '85',
#    '8.3',
#    '215',
#    '21.0',
#    'DISTRICT TOTAL',
#    'SCHOOL DISTRICT',
#    '50 UNION AVE',
#    'HARRISON',
#    'NY',
#    '10528',
#    ['{"address":"50 UNION AVE","city":"HARRISON","state":"NY","zip":"10528"}',
#     '40.9797534060005',
#     '-73.71683523299964',
#     None,
#     False]],
#   [3228,
#    '9AEA045C-2797-4A6A-B597-25BF4FE22C5C',
#    3228,
#    1411498111,
#    '698552',
#    1411498137,
#    '705890',
#    '{\n}',
#    '660501',
#    'WESTCHESTER',
#    'HARRISON CENTRAL SCHOOL',
#    'HUDSON VALLEY',
#    '2012-2013',
#    '168',
#    '23.3',
#    '84',
#    '11.7',
#    '252',
#    '35.0',
#    'ELEMENTARY',
#    'SCHOOL DISTRICT',
#    '50 UNION AVE',
#    'HARRISON',
#    'NY',
#    '10528',
#    ['{"address":"50 UNION AVE","city":"HARRISON","state":"NY","zip":"10528"}',
#     '40.9797534060005',
#     '-73.71683523299964',
#     None,
#     False]],
#   [3229,
#    '18EBECEF-C031-4B55-8EFB-605859B7F69D',
#    3229,
#    1411498111,
#    '698552',
#    1411498119,
#    '705890',
#    '{\n}',
#    '660501',
#    'WESTCHESTER',
#    'HARRISON CENTRAL SCHOOL',
#    'HUDSON VALLEY',
#    '2012-2013',
#    '39',
#    '12.0',
#    '28',
#    '8.6',
#    '67',
#    '20.6',
#    'MIDDLE/HIGH',
#    'SCHOOL DISTRICT',
#    '50 UNION AVE',
#    'HARRISON',
#    'NY',
#    '10528',
#    ['{"address":"50 UNION AVE","city":"HARRISON","state":"NY","zip":"10528"}',
#     '40.9797534060005',
#     '-73.71683523299964',
#     None,
#     False]],
#   [3230,
#    '362E308F-57D3-4987-8233-A58834624D0C',
#    3230,
#    1411498111,
#    '698552',
#    1411498122,
#    '705890',
#    '{\n}',
#    '660801',
#    'WESTCHESTER',
#    'MT PLEASANT CENTRAL SCHOOL',
#    'HUDSON VALLEY',
#    '2012-2013',
#    '114',
#    '17.0',
#    '79',
#    '11.8',
#    '193',
#    '28.8',
#    'DISTRICT TOTAL',
#    'SCHOOL DISTRICT',
#    '825 WESTLAKE DR',
#    'THORNWOOD',
#    'NY',
#    '10594',
#    ['{"address":"825 WESTLAKE DR","city":"THORNWOOD","state":"NY","zip":"10594"}',
#     '41.1130223400005',
#     '-73.76329651999964',
#     None,
#     False]],
#   [3231,
#    '9DE56FD8-B878-49ED-BD2B-415CEBD82A72',
#    3231,
#    1411498111,
#    '698552',
#    1411498137,
#    '705890',
#    '{\n}',
#    '660801',
#    'WESTCHESTER',
#    'MT PLEASANT CENTRAL SCHOOL',
#    'HUDSON VALLEY',
#    '2012-2013',
#    '65',
#    '15.0',
#    '51',
#    '11.8',
#    '116',
#    '26.8',
#    'ELEMENTARY',
#    'SCHOOL DISTRICT',
#    '825 WESTLAKE DR',
#    'THORNWOOD',
#    'NY',
#    '10594',
#    ['{"address":"825 WESTLAKE DR","city":"THORNWOOD","state":"NY","zip":"10594"}',
#     '41.1130223400005',
#     '-73.76329651999964',
#     None,
#     False]],
#   [3232,
#    'EC328566-A404-4097-A63E-C9C501964E0C',
#    3232,
#    1411498111,
#    '698552',
#    1411498141,
#    '705890',
#    '{\n}',
#    '660801',
#    'WESTCHESTER',
#    'MT PLEASANT CENTRAL SCHOOL',
#    'HUDSON VALLEY',
#    '2012-2013',
#    '49',
#    '21.2',
#    '28',
#    '12.1',
#    '77',
#    '33.3',
#    'MIDDLE/HIGH',
#    'SCHOOL DISTRICT',
#    '825 WESTLAKE DR',
#    'THORNWOOD',
#    'NY',
#    '10594',
#    ['{"address":"825 WESTLAKE DR","city":"THORNWOOD","state":"NY","zip":"10594"}',
#     '41.1130223400005',
#     '-73.76329651999964',
#     None,
#     False]],
#   [3233,
#    '3B76F257-B8BC-448D-A1F6-8F93C17870F4',
#    3233,
#    1411498111,
#    '698552',
#    1411498122,
#    '705890',
#    '{\n}',
#    '660805',
#    'WESTCHESTER',
#    'VALHALLA UNION FREE SCHOOL',
#    'HUDSON VALLEY',
#    '2012-2013',
#    '75',
#    '14.9',
#    '62',
#    '12.3',
#    '137',
#    '27.1',
#    'DISTRICT TOTAL',
#    'SCHOOL DISTRICT',
#    '316 COLUMBUS AVE',
#    'VALHALLA',
#    'NY',
#    '10595',
#    ['{"address":"316 COLUMBUS AVE","city":"VALHALLA","state":"NY","zip":"10595"}',
#     '41.09183251000047',
#     '-73.77740930199963',
#     None,
#     False]],
#   [3234,
#    '30B9A9D6-91CC-42CD-94BA-6FE756B618DC',
#    3234,
#    1411498111,
#    '698552',
#    1411498122,
#    '705890',
#    '{\n}',
#    '660805',
#    'WESTCHESTER',
#    'VALHALLA UNION FREE SCHOOL',
#    'HUDSON VALLEY',
#    '2012-2013',
#    '46',
#    '15.1',
#    '35',
#    '11.5',
#    '81',
#    '26.6',
#    'ELEMENTARY',
#    'SCHOOL DISTRICT',
#    '316 COLUMBUS AVE',
#    'VALHALLA',
#    'NY',
#    '10595',
#    ['{"address":"316 COLUMBUS AVE","city":"VALHALLA","state":"NY","zip":"10595"}',
#     '41.09183251000047',
#     '-73.77740930199963',
#     None,
#     False]],
#   [3235,
#    '84F952FF-97D6-4C77-9591-F481FC7D87D9',
#    3235,
#    1411498111,
#    '698552',
#    1411498136,
#    '705890',
#    '{\n}',
#    '660805',
#    'WESTCHESTER',
#    'VALHALLA UNION FREE SCHOOL',
#    'HUDSON VALLEY',
#    '2012-2013',
#    '29',
#    '14.7',
#    '27',
#    '13.7',
#    '56',
#    '28.4',
#    'MIDDLE/HIGH',
#    'SCHOOL DISTRICT',
#    '316 COLUMBUS AVE',
#    'VALHALLA',
#    'NY',
#    '10595',
#    ['{"address":"316 COLUMBUS AVE","city":"VALHALLA","state":"NY","zip":"10595"}',
#     '41.09183251000047',
#     '-73.77740930199963',
#     None,
#     False]],
#   [3236,
#    '0D24B45C-12A7-4222-9FCE-F05710FA54D2',
#    3236,
#    1411498111,
#    '698552',
#    1411498119,
#    '705890',
#    '{\n}',
#    '660809',
#    'WESTCHESTER',
#    'PLEASANTVILLE U F S',
#    'HUDSON VALLEY',
#    '2012-2013',
#    '64',
#    '13.3',
#    '37',
#    '7.7',
#    '101',
#    '21.0',
#    'DISTRICT TOTAL',
#    'SCHOOL DISTRICT',
#    '60 ROMER AVE',
#    'PLEASANTVILLE',
#    'NY',
#    '10570',
#    ['{"address":"60 ROMER AVE","city":"PLEASANTVILLE","state":"NY","zip":"10570"}',
#     '41.134073388000445',
#     '-73.78535361899964',
#     None,
#     False]],
#   ...]}

# %%
json_data.close()

# %% [markdown]
# # 3. Data Cleansing

# %% [markdown]
# # 3.1. Valores perdidos

# %%
# Identificar a los valores perdidos.
d['REGION'].isnull().head()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# Name: REGION, dtype: bool

# %%
# Identificar a los valores no perdidos.
d['PCT OVERWEIGHT'].notnull().head()
# Out:
# 0    True
# 1    True
# 2    True
# 3    True
# 4    True
# Name: PCT OVERWEIGHT, dtype: bool

# %%
# Cuantificar a los valores perdidos.
d['PCT OVERWEIGHT'].isnull().value_counts()
# Out:
# False    3078
# True      192
# Name: PCT OVERWEIGHT, dtype: int64

# %%
# Cuantificar a los valores no perdidos.
d['PCT OVERWEIGHT'].notnull().value_counts()
# Out:
# True     3078
# False     192
# Name: PCT OVERWEIGHT, dtype: int64

# %%
# Eliminar a los valores perdidos.
d['PCT OVERWEIGHT'].dropna()
# Out:
# 0       0.185
# 1       0.192
# 2       0.176
# 3       0.172
# 4       0.161
# 5       0.202
# 6       0.159
# 7       0.174
# 8       0.139
# 9       0.163
# 10      0.155
# 11      0.169
# 12      0.176
# 15      0.130
# 16      0.126
# 17      0.136
# 18      0.211
# 19      0.219
# 20      0.209
# 21      0.143
# 24      0.175
# 25      0.214
# 27      0.208
# 28      0.222
# 29      0.333
# 30      0.163
# 31      0.158
# 32      0.180
# 33      0.166
# 34      0.116
#         ...
# 3239    0.152
# 3240    0.168
# 3241    0.168
# 3242    0.167
# 3243    0.161
# 3244    0.153
# 3245    0.171
# 3246    0.144
# 3247    0.124
# 3248    0.171
# 3249    0.191
# 3250    0.177
# 3251    0.212
# 3252    0.164
# 3253    0.188
# 3255    0.188
# 3256    0.181
# 3257    0.196
# 3258    0.213
# 3259    0.217
# 3260    0.214
# 3261    0.173
# 3262    0.182
# 3263    0.172
# 3264    0.160
# 3265    0.156
# 3266    0.156
# 3267    0.158
# 3268    0.152
# 3269    0.171
# Name: PCT OVERWEIGHT, Length: 3078, dtype: float64

# %%
d.head()
# Out:
#    LOCATION CODE  COUNTY                                        AREA NAME  \
# 0          10402  ALBANY  RAVENA COEYMANS SELKIRK CENTRAL SCHOOL DISTRICT
# 1          10402  ALBANY  RAVENA COEYMANS SELKIRK CENTRAL SCHOOL DISTRICT
# 2          10402  ALBANY  RAVENA COEYMANS SELKIRK CENTRAL SCHOOL DISTRICT
# 3          10500  ALBANY                      COHOES CITY SCHOOL DISTRICT
# 4          10500  ALBANY                      COHOES CITY SCHOOL DISTRICT
#
#                   REGION SCHOOL YEARS  NO. OVERWEIGHT  PCT OVERWEIGHT  \
# 0  NORTHEASTERN NEW YORK    2012-2013           124.0           0.185
# 1  NORTHEASTERN NEW YORK    2012-2013            74.0           0.192
# 2  NORTHEASTERN NEW YORK    2012-2013            50.0           0.176
# 3  NORTHEASTERN NEW YORK    2012-2013            84.0           0.172
# 4  NORTHEASTERN NEW YORK    2012-2013            58.0           0.161
#
#    NO. OBESE  PCT OBESE  NO. OVERWEIGHT OR OBESE  PCT OVERWEIGHT OR OBESE  \
# 0      139.0      0.208                    263.0                    0.393
# 1       72.0      0.187                    146.0                    0.379
# 2       67.0      0.236                    117.0                    0.412
# 3      124.0      0.254                    208.0                    0.425
# 4       89.0      0.247                    147.0                    0.408
#
#       GRADE LEVEL        AREA TYPE  STREET ADDRESS    CITY STATE  ZIP CODE  \
# 0  DISTRICT TOTAL  SCHOOL DISTRICT  15 MOUNTAIN RD  RAVENA    NY   12143.0
# 1      ELEMENTARY  SCHOOL DISTRICT  15 MOUNTAIN RD  RAVENA    NY   12143.0
# 2     MIDDLE/HIGH  SCHOOL DISTRICT  15 MOUNTAIN RD  RAVENA    NY   12143.0
# 3  DISTRICT TOTAL  SCHOOL DISTRICT      7 BEVAN ST  COHOES    NY   12047.0
# 4      ELEMENTARY  SCHOOL DISTRICT      7 BEVAN ST  COHOES    NY   12047.0
#
#                                           Location 1
# 0  15 MOUNTAIN RD\nRAVENA, NY 12143\n(42.47227638...
# 1  15 MOUNTAIN RD\nRAVENA, NY 12143\n(42.47227638...
# 2  15 MOUNTAIN RD\nRAVENA, NY 12143\n(42.47227638...
# 3  7 BEVAN ST\nCOHOES, NY 12047\n(42.771285452000...
# 4  7 BEVAN ST\nCOHOES, NY 12047\n(42.771285452000...

# %%
# Eliminar a cualquier registro que tenga por lo menos un campo con valor perdido.
d = d.dropna(how='any')

# %%
d.head()
# Out:
#    LOCATION CODE  COUNTY                                        AREA NAME  \
# 0          10402  ALBANY  RAVENA COEYMANS SELKIRK CENTRAL SCHOOL DISTRICT
# 1          10402  ALBANY  RAVENA COEYMANS SELKIRK CENTRAL SCHOOL DISTRICT
# 2          10402  ALBANY  RAVENA COEYMANS SELKIRK CENTRAL SCHOOL DISTRICT
# 3          10500  ALBANY                      COHOES CITY SCHOOL DISTRICT
# 4          10500  ALBANY                      COHOES CITY SCHOOL DISTRICT
#
#                   REGION SCHOOL YEARS  NO. OVERWEIGHT  PCT OVERWEIGHT  \
# 0  NORTHEASTERN NEW YORK    2012-2013           124.0           0.185
# 1  NORTHEASTERN NEW YORK    2012-2013            74.0           0.192
# 2  NORTHEASTERN NEW YORK    2012-2013            50.0           0.176
# 3  NORTHEASTERN NEW YORK    2012-2013            84.0           0.172
# 4  NORTHEASTERN NEW YORK    2012-2013            58.0           0.161
#
#    NO. OBESE  PCT OBESE  NO. OVERWEIGHT OR OBESE  PCT OVERWEIGHT OR OBESE  \
# 0      139.0      0.208                    263.0                    0.393
# 1       72.0      0.187                    146.0                    0.379
# 2       67.0      0.236                    117.0                    0.412
# 3      124.0      0.254                    208.0                    0.425
# 4       89.0      0.247                    147.0                    0.408
#
#       GRADE LEVEL        AREA TYPE  STREET ADDRESS    CITY STATE  ZIP CODE  \
# 0  DISTRICT TOTAL  SCHOOL DISTRICT  15 MOUNTAIN RD  RAVENA    NY   12143.0
# 1      ELEMENTARY  SCHOOL DISTRICT  15 MOUNTAIN RD  RAVENA    NY   12143.0
# 2     MIDDLE/HIGH  SCHOOL DISTRICT  15 MOUNTAIN RD  RAVENA    NY   12143.0
# 3  DISTRICT TOTAL  SCHOOL DISTRICT      7 BEVAN ST  COHOES    NY   12047.0
# 4      ELEMENTARY  SCHOOL DISTRICT      7 BEVAN ST  COHOES    NY   12047.0
#
#                                           Location 1
# 0  15 MOUNTAIN RD\nRAVENA, NY 12143\n(42.47227638...
# 1  15 MOUNTAIN RD\nRAVENA, NY 12143\n(42.47227638...
# 2  15 MOUNTAIN RD\nRAVENA, NY 12143\n(42.47227638...
# 3  7 BEVAN ST\nCOHOES, NY 12047\n(42.771285452000...
# 4  7 BEVAN ST\nCOHOES, NY 12047\n(42.771285452000...

# %%
# Cuantificar a los valores perdidos.
d['PCT OVERWEIGHT'].isnull().value_counts()
# Out:
# False    2833
# Name: PCT OVERWEIGHT, dtype: int64

# %% [markdown]
# # 3.2. Imputar Valores Perdidos

# %%
import numpy as np

# %%
# Crear un data frame en base a números aleatorios.
df = pd.DataFrame(np.random.randn(5, 3), index=['a0', 'a10','a20', 'a30', 'a40'],columns=['X', 'Y', 'Z'])
df
# Out:
#             X         Y         Z
# a0   2.210862  1.326322 -2.051380
# a10 -0.808142 -0.537444  1.533836
# a20  0.569962  0.167416  1.033262
# a30 -0.411448  1.211713 -0.307406
# a40  1.747007 -0.862352 -1.495515

# %%
# Crear índices adicionales al data frame.
df2 = df.reindex(['a0', 'a1', 'a10', 'a11', 'a20', 'a21','a30', 'a31', 'a40', 'a41'])
df2
# Out:
#             X         Y         Z
# a0   2.210862  1.326322 -2.051380
# a1        NaN       NaN       NaN
# a10 -0.808142 -0.537444  1.533836
# a11       NaN       NaN       NaN
# a20  0.569962  0.167416  1.033262
# a21       NaN       NaN       NaN
# a30 -0.411448  1.211713 -0.307406
# a31       NaN       NaN       NaN
# a40  1.747007 -0.862352 -1.495515
# a41       NaN       NaN       NaN

# %%
# Completar los valores perdidos con ceros.
df3 = df2.fillna(0)
df3
# Out:
#             X         Y         Z
# a0   2.210862  1.326322 -2.051380
# a1   0.000000  0.000000  0.000000
# a10 -0.808142 -0.537444  1.533836
# a11  0.000000  0.000000  0.000000
# a20  0.569962  0.167416  1.033262
# a21  0.000000  0.000000  0.000000
# a30 -0.411448  1.211713 -0.307406
# a31  0.000000  0.000000  0.000000
# a40  1.747007 -0.862352 -1.495515
# a41  0.000000  0.000000  0.000000

# %%
# Completar los valores perdidos con el método “forward propagation”. Se va completar con el valor previo al nulo.
df4 = df2.fillna(method='pad')
df4
# Out:
#             X         Y         Z
# a0   2.210862  1.326322 -2.051380
# a1   2.210862  1.326322 -2.051380
# a10 -0.808142 -0.537444  1.533836
# a11 -0.808142 -0.537444  1.533836
# a20  0.569962  0.167416  1.033262
# a21  0.569962  0.167416  1.033262
# a30 -0.411448  1.211713 -0.307406
# a31 -0.411448  1.211713 -0.307406
# a40  1.747007 -0.862352 -1.495515
# a41  1.747007 -0.862352 -1.495515

# %%
# Completar los valores perdidos con el promedio de la variable.
df5 = df2.fillna(df2.mean())
df5
# Out:
#             X         Y         Z
# a0  -0.009508  0.651917  1.503900
# a1  -0.151875  0.228622  1.181985
# a10 -0.717419  0.166382  1.516967
# a11 -0.151875  0.228622  1.181985
# a20 -0.821223  1.106835  1.180634
# a21 -0.151875  0.228622  1.181985
# a30 -0.295569 -0.875346  1.687973
# a31 -0.151875  0.228622  1.181985
# a40  1.084346  0.093323  0.020450
# a41 -0.151875  0.228622  1.181985

# %%
df22 = df.reindex(['a99','a0', 'a1', 'a10', 'a11', 'a20', 'a21','a30', 'a31', 'a40', 'a41'])
df22
# Out:
#             X         Y         Z
# a99       NaN       NaN       NaN
# a0   2.210862  1.326322 -2.051380
# a1        NaN       NaN       NaN
# a10 -0.808142 -0.537444  1.533836
# a11       NaN       NaN       NaN
# a20  0.569962  0.167416  1.033262
# a21       NaN       NaN       NaN
# a30 -0.411448  1.211713 -0.307406
# a31       NaN       NaN       NaN
# a40  1.747007 -0.862352 -1.495515
# a41       NaN       NaN       NaN

# %%
df22.fillna(method='pad')
# Out:
#             X         Y         Z
# a99       NaN       NaN       NaN
# a0   2.210862  1.326322 -2.051380
# a1   2.210862  1.326322 -2.051380
# a10 -0.808142 -0.537444  1.533836
# a11 -0.808142 -0.537444  1.533836
# a20  0.569962  0.167416  1.033262
# a21  0.569962  0.167416  1.033262
# a30 -0.411448  1.211713 -0.307406
# a31 -0.411448  1.211713 -0.307406
# a40  1.747007 -0.862352 -1.495515
# a41  1.747007 -0.862352 -1.495515

# %%
from sklearn.preprocessing import Imputer
imp = Imputer(missing_values="NaN", strategy='median', axis=0)
df23 = imp.fit_transform(df22)

# %%
df23
# Out:
# array([[ 0.56996153,  0.16741578, -0.30740588],
#        [ 2.21086242,  1.32632216, -2.05138013],
#        [ 0.56996153,  0.16741578, -0.30740588],
#        [-0.80814194, -0.53744385,  1.53383551],
#        [ 0.56996153,  0.16741578, -0.30740588],
#        [ 0.56996153,  0.16741578,  1.03326152],
#        [ 0.56996153,  0.16741578, -0.30740588],
#        [-0.41144772,  1.21171256, -0.30740588],
#        [ 0.56996153,  0.16741578, -0.30740588],
#        [ 1.74700698, -0.8623521 , -1.49551506],
#        [ 0.56996153,  0.16741578, -0.30740588]])

# %%
df24 = pd.DataFrame(df23)

# %%
df24
# Out:
#            0         1         2
# 0   0.569962  0.167416 -0.307406
# 1   2.210862  1.326322 -2.051380
# 2   0.569962  0.167416 -0.307406
# 3  -0.808142 -0.537444  1.533836
# 4   0.569962  0.167416 -0.307406
# 5   0.569962  0.167416  1.033262
# 6   0.569962  0.167416 -0.307406
# 7  -0.411448  1.211713 -0.307406
# 8   0.569962  0.167416 -0.307406
# 9   1.747007 -0.862352 -1.495515
# 10  0.569962  0.167416 -0.307406

# %% [markdown]
# # 3.3. Operaciones con cadenas

# %%
# Importar un archivo csv y leer los 5 primeros casos.
df = pd.read_csv('../0_Data/students.csv')
df['AREA NAME'][0:5]
# Out:
# 0    RAVENA COEYMANS SELKIRK CENTRAL SCHOOL DISTRICT
# 1    RAVENA COEYMANS SELKIRK CENTRAL SCHOOL DISTRICT
# 2    RAVENA COEYMANS SELKIRK CENTRAL SCHOOL DISTRICT
# 3                        COHOES CITY SCHOOL DISTRICT
# 4                        COHOES CITY SCHOOL DISTRICT
# Name: AREA NAME, dtype: object

# %%
# Extraer las dos primeras palabras de los 5 primeros casos.
df['AREA NAME'][0:5].str.extract('(\w+)\s(\w+)\s(\w+)\s(\w+)')
# Out:
#         0         1        2         3
# 0  RAVENA  COEYMANS  SELKIRK   CENTRAL
# 1  RAVENA  COEYMANS  SELKIRK   CENTRAL
# 2  RAVENA  COEYMANS  SELKIRK   CENTRAL
# 3  COHOES      CITY   SCHOOL  DISTRICT
# 4  COHOES      CITY   SCHOOL  DISTRICT

# %%
# Filtrar casos específicos.
df[df['GRADE LEVEL'] == 'ELEMENTARY']
# Out:
#       LOCATION CODE       COUNTY  \
# 1             10402       ALBANY
# 4             10500       ALBANY
# 7             10601       ALBANY
# 10            10623       ALBANY
# 13            10701       ALBANY
# 16            10802       ALBANY
# 19            20101     ALLEGANY
# 22            21102     ALLEGANY
# 25            21601     ALLEGANY
# 28            22101     ALLEGANY
# 31            22601     ALLEGANY
# 34            22902     ALLEGANY
# 37            30101       BROOME
# 40            30200       BROOME
# 43            30501       BROOME
# 46            30601       BROOME
# 49            30701       BROOME
# 52            31701       BROOME
# 55            40302  CATTARAUGUS
# 58            40901  CATTARAUGUS
# 61            41401  CATTARAUGUS
# 64            42400  CATTARAUGUS
# 67            43001  CATTARAUGUS
# 70            43200  CATTARAUGUS
# 73            50301       CAYUGA
# 76            50401       CAYUGA
# 79            51301       CAYUGA
# 82            60301   CHAUTAUQUA
# 85            60401   CHAUTAUQUA
# 88            60701   CHAUTAUQUA
# ...             ...          ...
# 3181         660802  WESTCHESTER
# 3184         660805  WESTCHESTER
# 3187         660809  WESTCHESTER
# 3190         660900  WESTCHESTER
# 3193         661004  WESTCHESTER
# 3196         661100  WESTCHESTER
# 3199         661201  WESTCHESTER
# 3202         661301  WESTCHESTER
# 3205         661401  WESTCHESTER
# 3208         661402  WESTCHESTER
# 3211         661500  WESTCHESTER
# 3214         661601  WESTCHESTER
# 3217         661800  WESTCHESTER
# 3220         661901  WESTCHESTER
# 3223         661904  WESTCHESTER
# 3226         661905  WESTCHESTER
# 3229         662001  WESTCHESTER
# 3232         662101  WESTCHESTER
# 3235         662200  WESTCHESTER
# 3238         662300  WESTCHESTER
# 3241         662401  WESTCHESTER
# 3244         662402  WESTCHESTER
# 3247         670201      WYOMING
# 3250         670401      WYOMING
# 3253         671002      WYOMING
# 3256         671201      WYOMING
# 3259         671501      WYOMING
# 3262         680601        YATES
# 3265         680801        YATES
# 3268         700000          NaN
#
#                                             AREA NAME                 REGION  \
# 1     RAVENA COEYMANS SELKIRK CENTRAL SCHOOL DISTRICT  NORTHEASTERN NEW YORK
# 4                         COHOES CITY SCHOOL DISTRICT  NORTHEASTERN NEW YORK
# 7               SOUTH COLONIE CENTRAL SCHOOL DISTRICT  NORTHEASTERN NEW YORK
# 10              NORTH COLONIE CENTRAL SCHOOL DISTRICT  NORTHEASTERN NEW YORK
# 13            GREEN ISLAND UNION FREE SCHOOL DISTRICT  NORTHEASTERN NEW YORK
# 16                GUILDERLAND CENTRAL SCHOOL DISTRICT  NORTHEASTERN NEW YORK
# 19              ALFRED ALMOND CENTRAL SCHOOL DISTRICT       WESTERN NEW YORK
# 22                 CANASERAGA CENTRAL SCHOOL DISTRICT       WESTERN NEW YORK
# 25                 FRIENDSHIP CENTRAL SCHOOL DISTRICT       WESTERN NEW YORK
# 28                WHITESVILLE CENTRAL SCHOOL DISTRICT       WESTERN NEW YORK
# 31                 WELLSVILLE CENTRAL SCHOOL DISTRICT       WESTERN NEW YORK
# 34           BOLIVAR-RICHBURG CENTRAL SCHOOL DISTRICT       WESTERN NEW YORK
# 37             CHENANGO FORKS CENTRAL SCHOOL DISTRICT        NEW YORK - PENN
# 40                    BINGHAMTON CITY SCHOOL DISTRICT        NEW YORK - PENN
# 43               HARPURSVILLE CENTRAL SCHOOL DISTRICT        NEW YORK - PENN
# 46         SUSQUEHANNA VALLEY CENTRAL SCHOOL DISTRICT        NEW YORK - PENN
# 49            CHENANGO VALLEY CENTRAL SCHOOL DISTRICT        NEW YORK - PENN
# 52                    WINDSOR CENTRAL SCHOOL DISTRICT        NEW YORK - PENN
# 55                             ALLEGANY-LIMESTONE CSD       WESTERN NEW YORK
# 58              ELLICOTTVILLE CENTRAL SCHOOL DISTRICT       WESTERN NEW YORK
# 61                   HINSDALE CENTRAL SCHOOL DISTRICT       WESTERN NEW YORK
# 64                                 OLEAN CITY SCHOOLS       WESTERN NEW YORK
# 67                   RANDOLPH CENTRAL SCHOOL DISTRICT       WESTERN NEW YORK
# 70                             SALAMANCA CITY SCHOOLS       WESTERN NEW YORK
# 73                  WEEDSPORT CENTRAL SCHOOL DISTRICT       CENTRAL NEW YORK
# 76              CATO MERIDIAN CENTRAL SCHOOL DISTRICT       CENTRAL NEW YORK
# 79                    MORAVIA CENTRAL SCHOOL DISTRICT       CENTRAL NEW YORK
# 82                  FREWSBURG CENTRAL SCHOOL DISTRICT       WESTERN NEW YORK
# 85           CASSADAGA VALLEY CENTRAL SCHOOL DISTRICT       WESTERN NEW YORK
# 88                     CLYMER CENTRAL SCHOOL DISTRICT       WESTERN NEW YORK
# ...                                               ...                    ...
# 3181                   POCANTICO HILLS CENTRAL SCHOOL          HUDSON VALLEY
# 3184                       VALHALLA UNION FREE SCHOOL          HUDSON VALLEY
# 3187                              PLEASANTVILLE U F S          HUDSON VALLEY
# 3190                        MOUNT VERNON CITY SCHOOLS          HUDSON VALLEY
# 3193                         CHAPPAQUA CENTRAL SCHOOL          HUDSON VALLEY
# 3196                        NEW ROCHELLE CITY SCHOOLS          HUDSON VALLEY
# 3199                       BYRAM HILLS CENTRAL SCHOOL          HUDSON VALLEY
# 3202              NORTH SALEM CENTRAL SCHOOL DISTRICT          HUDSON VALLEY
# 3205                       OSSINING UNION FREE SCHOOL          HUDSON VALLEY
# 3208                           BRIARCLIFF MANOR U F S          HUDSON VALLEY
# 3211                           PEEKSKILL CITY SCHOOLS          HUDSON VALLEY
# 3214                         PELHAM UNION FREE SCHOOL          HUDSON VALLEY
# 3217                         RYE CITY SCHOOL DISTRICT          HUDSON VALLEY
# 3220                       RYE NECK UNION FREE SCHOOL          HUDSON VALLEY
# 3223                           PORT CHESTER-RYE U F S          HUDSON VALLEY
# 3226                             BLIND BROOK-RYE UFSD          HUDSON VALLEY
# 3229                      SCARSDALE UNION FREE SCHOOL          HUDSON VALLEY
# 3232                            SOMERS CENTRAL SCHOOL          HUDSON VALLEY
# 3235                        WHITE PLAINS CITY SCHOOLS          HUDSON VALLEY
# 3238                             YONKERS CITY SCHOOLS          HUDSON VALLEY
# 3241                 LAKELAND CENTRAL SCHOOL DISTRICT          HUDSON VALLEY
# 3244                          YORKTOWN CENTRAL SCHOOL          HUDSON VALLEY
# 3247                            ATTICA CENTRAL SCHOOL       WESTERN NEW YORK
# 3250               LETCHWORTH CENT SCH AT GAINESVILLE       WESTERN NEW YORK
# 3253                           WYOMING CENTRAL SCHOOL       WESTERN NEW YORK
# 3256                             PERRY CENTRAL SCHOOL       WESTERN NEW YORK
# 3259                            WARSAW CENTRAL SCHOOL       WESTERN NEW YORK
# 3262                          PENN YAN CENTRAL SCHOOL           FINGER LAKES
# 3265                            DUNDEE CENTRAL SCHOOL           FINGER LAKES
# 3268                                 WESTERN NEW YORK       WESTERN NEW YORK
#
#      SCHOOL YEARS  NO. OVERWEIGHT PCT OVERWEIGHT  NO. OBESE PCT OBESE  \
# 1       2012-2013            74.0          19.2%       72.0     18.7%
# 4       2012-2013            58.0          16.1%       89.0     24.7%
# 7       2012-2013           145.0          17.4%      169.0     20.3%
# 10      2012-2013            94.0          15.5%       78.0     12.9%
# 13      2012-2013             NaN            NaN       15.0     35.7%
# 16      2012-2013           103.0          12.6%      113.0     13.8%
# 19      2012-2013            21.0          21.9%        9.0      9.4%
# 22      2012-2013             NaN            NaN        NaN       NaN
# 25      2012-2013            24.0          21.4%       15.0     13.4%
# 28      2012-2013             8.0          22.2%        5.0     13.9%
# 31      2012-2013            43.0          15.8%       44.0     16.1%
# 34      2012-2013            26.0          11.6%       31.0     13.8%
# 37      2012-2013            51.0            15%       61.0     17.9%
# 40      2012-2013           254.0          20.5%      264.0     21.3%
# 43      2012-2013            51.0          24.5%       42.0     20.2%
# 46      2012-2013            46.0          15.6%       51.0     17.3%
# 49      2012-2013            46.0          13.9%       56.0     16.9%
# 52      2012-2013            54.0          13.9%       65.0     16.7%
# 55      2012-2013            69.0          17.4%       56.0     14.1%
# 58      2012-2013            30.0          20.3%       23.0     15.5%
# 61      2012-2013            24.0            17%       19.0     13.5%
# 64      2012-2013            87.0          19.4%       85.0     18.9%
# 67      2012-2013            24.0          14.2%       25.0     14.8%
# 70      2012-2013            54.0          15.1%       75.0       21%
# 73      2012-2013            25.0          14.9%       27.0     16.1%
# 76      2012-2013             8.0           3.4%       23.0      9.8%
# 79      2012-2013            51.0          21.9%       50.0     21.5%
# 82      2012-2013            31.0          12.9%       22.0      9.2%
# 85      2012-2013            41.0            16%       57.0     22.2%
# 88      2012-2013            12.0            14%       13.0     15.1%
# ...           ...             ...            ...        ...       ...
# 3181    2010-2012             6.0          11.3%        6.0     11.3%
# 3184    2010-2012            64.0          17.9%       33.0      9.2%
# 3187    2010-2012            25.0           9.8%       14.0      5.5%
# 3190    2010-2012           207.0          15.3%      267.0     19.7%
# 3193    2010-2012           106.0          15.5%       66.0      9.6%
# 3196    2010-2012           341.0          15.6%      472.0     21.6%
# 3199    2010-2012            62.0          12.8%       24.0        5%
# 3202    2010-2012            33.0          13.8%       13.0      5.4%
# 3205    2010-2012           200.0          18.8%      222.0     20.9%
# 3208    2010-2012            20.0             9%       18.0      8.1%
# 3211    2010-2012            33.0          16.7%       44.0     22.2%
# 3214    2010-2012            42.0           8.3%       51.0       10%
# 3217    2010-2012            97.0          14.7%       53.0        8%
# 3220    2010-2012            45.0          12.7%       31.0      8.8%
# 3223    2010-2012           125.0          16.8%      210.0     28.2%
# 3226    2010-2012            39.0          11.7%       25.0      7.5%
# 3229    2010-2012            41.0          10.7%       22.0      5.7%
# 3232    2010-2012           107.0          19.7%       40.0      7.4%
# 3235    2010-2012            92.0          12.1%      153.0     20.1%
# 3238    2010-2012           338.0          13.8%      460.0     18.8%
# 3241    2010-2012           122.0          16.8%      107.0     14.8%
# 3244    2010-2012            88.0          15.3%       70.0     12.1%
# 3247    2010-2012            30.0          12.4%       46.0       19%
# 3250    2010-2012            32.0          17.7%       22.0     12.2%
# 3253    2010-2012             9.0          18.8%        NaN       NaN
# 3256    2010-2012            35.0          18.1%       49.0     25.4%
# 3259    2010-2012            45.0          21.7%       45.0     21.7%
# 3262    2010-2012            45.0          18.2%       48.0     19.4%
# 3265    2010-2012            28.0          15.6%       20.0     11.1%
# 3268    2010-2012          5827.0          15.2%     6587.0     17.1%
#
#       NO. OVERWEIGHT OR OBESE PCT OVERWEIGHT OR OBESE GRADE LEVEL  \
# 1                       146.0                   37.9%  ELEMENTARY
# 4                       147.0                   40.8%  ELEMENTARY
# 7                       314.0                   37.8%  ELEMENTARY
# 10                      172.0                   28.4%  ELEMENTARY
# 13                       15.0                   35.7%  ELEMENTARY
# 16                      216.0                   26.4%  ELEMENTARY
# 19                       30.0                   31.3%  ELEMENTARY
# 22                        NaN                     NaN  ELEMENTARY
# 25                       39.0                   34.8%  ELEMENTARY
# 28                       13.0                   36.1%  ELEMENTARY
# 31                       87.0                   31.9%  ELEMENTARY
# 34                       57.0                   25.4%  ELEMENTARY
# 37                      112.0                   32.8%  ELEMENTARY
# 40                      518.0                   41.8%  ELEMENTARY
# 43                       93.0                   44.7%  ELEMENTARY
# 46                       97.0                     33%  ELEMENTARY
# 49                      102.0                   30.7%  ELEMENTARY
# 52                      119.0                   30.6%  ELEMENTARY
# 55                      125.0                   31.6%  ELEMENTARY
# 58                       53.0                   35.8%  ELEMENTARY
# 61                       43.0                   30.5%  ELEMENTARY
# 64                      172.0                   38.3%  ELEMENTARY
# 67                       49.0                     29%  ELEMENTARY
# 70                      129.0                   36.1%  ELEMENTARY
# 73                       52.0                     31%  ELEMENTARY
# 76                       31.0                   13.2%  ELEMENTARY
# 79                      101.0                   43.3%  ELEMENTARY
# 82                       53.0                   22.1%  ELEMENTARY
# 85                       98.0                   38.1%  ELEMENTARY
# 88                       25.0                   29.1%  ELEMENTARY
# ...                       ...                     ...         ...
# 3181                     12.0                   22.6%  ELEMENTARY
# 3184                     97.0                   27.1%  ELEMENTARY
# 3187                     39.0                   15.4%  ELEMENTARY
# 3190                    474.0                     35%  ELEMENTARY
# 3193                    172.0                   25.1%  ELEMENTARY
# 3196                    813.0                   37.2%  ELEMENTARY
# 3199                     86.0                   17.8%  ELEMENTARY
# 3202                     46.0                   19.2%  ELEMENTARY
# 3205                    422.0                   39.7%  ELEMENTARY
# 3208                     38.0                   17.2%  ELEMENTARY
# 3211                     77.0                   38.9%  ELEMENTARY
# 3214                     93.0                   18.3%  ELEMENTARY
# 3217                    150.0                   22.7%  ELEMENTARY
# 3220                     76.0                   21.5%  ELEMENTARY
# 3223                    335.0                   44.9%  ELEMENTARY
# 3226                     64.0                   19.3%  ELEMENTARY
# 3229                     63.0                   16.4%  ELEMENTARY
# 3232                    147.0                     27%  ELEMENTARY
# 3235                    245.0                   32.2%  ELEMENTARY
# 3238                    798.0                   32.6%  ELEMENTARY
# 3241                    229.0                   31.6%  ELEMENTARY
# 3244                    158.0                   27.4%  ELEMENTARY
# 3247                     76.0                   31.4%  ELEMENTARY
# 3250                     54.0                   29.8%  ELEMENTARY
# 3253                      9.0                   18.8%  ELEMENTARY
# 3256                     84.0                   43.5%  ELEMENTARY
# 3259                     90.0                   43.5%  ELEMENTARY
# 3262                     93.0                   37.7%  ELEMENTARY
# 3265                     48.0                   26.7%  ELEMENTARY
# 3268                  12414.0                   32.3%  ELEMENTARY
#
#             AREA TYPE                   STREET ADDRESS                CITY  \
# 1     SCHOOL DISTRICT                   15 MOUNTAIN RD              RAVENA
# 4     SCHOOL DISTRICT                       7 BEVAN ST              COHOES
# 7     SCHOOL DISTRICT                   102 LORALEE DR              ALBANY
# 10    SCHOOL DISTRICT                   91 FIDDLERS LN              LATHAM
# 13    SCHOOL DISTRICT                   171 HUDSON AVE        GREEN ISLAND
# 16    SCHOOL DISTRICT                      8 SCHOOL RD  GUILDERLAND CENTER
# 19    SCHOOL DISTRICT                       6795 RT 21              ALMOND
# 22    SCHOOL DISTRICT                      4-8 MAIN ST          CANASERAGA
# 25    SCHOOL DISTRICT                     46 W MAIN ST          FRIENDSHIP
# 28    SCHOOL DISTRICT                      692 MAIN ST         WHITESVILLE
# 31    SCHOOL DISTRICT                126 WEST STATE ST          WELLSVILLE
# 34    SCHOOL DISTRICT                    100 SCHOOL ST             BOLIVAR
# 37    SCHOOL DISTRICT                      1 GORDON DR          BINGHAMTON
# 40    SCHOOL DISTRICT                    164 HAWLEY ST          BINGHAMTON
# 43    SCHOOL DISTRICT                       54 MAIN ST        HARPURSVILLE
# 46    SCHOOL DISTRICT                  1040 CONKLIN RD             CONKLIN
# 49    SCHOOL DISTRICT           221 CHENANGO BRIDGE RD          BINGHAMTON
# 52    SCHOOL DISTRICT                    1191 NY RT 79             WINDSOR
# 55    SCHOOL DISTRICT                3131 FIVE MILE RD            ALLEGANY
# 58    SCHOOL DISTRICT                      5873 RT 219       ELLICOTTVILLE
# 61    SCHOOL DISTRICT                     3701 MAIN ST            HINSDALE
# 64    SCHOOL DISTRICT                410 W SULLIVAN ST               OLEAN
# 67    SCHOOL DISTRICT                       18 MAIN ST            RANDOLPH
# 70    SCHOOL DISTRICT                   50 IROQUOIS DR           SALAMANCA
# 73    SCHOOL DISTRICT                 2821 E BRUTUS ST           WEEDSPORT
# 76    SCHOOL DISTRICT                  2851 NYS RT 370                CATO
# 79    SCHOOL DISTRICT                     68 S MAIN ST             MORAVIA
# 82    SCHOOL DISTRICT                  26 INSTITUTE ST           FREWSBURG
# 85    SCHOOL DISTRICT                       5935 RT 60       SINCLAIRVILLE
# 88    SCHOOL DISTRICT                   8672 E MAIN ST              CLYMER
# ...               ...                              ...                 ...
# 3181  SCHOOL DISTRICT                   599 BEDFORD RD       SLEEPY HOLLOW
# 3184  SCHOOL DISTRICT                 316 COLUMBUS AVE            VALHALLA
# 3187  SCHOOL DISTRICT                     60 ROMER AVE       PLEASANTVILLE
# 3190  SCHOOL DISTRICT               165 N COLUMBUS AVE        MOUNT VERNON
# 3193  SCHOOL DISTRICT              66 ROARING BROOK RD           CHAPPAQUA
# 3196  SCHOOL DISTRICT                    515 NORTH AVE        NEW ROCHELLE
# 3199  SCHOOL DISTRICT                      10 TRIPP LN              ARMONK
# 3202  SCHOOL DISTRICT                     230  JUNE RD         NORTH SALEM
# 3205  SCHOOL DISTRICT                   190 CROTON AVE            OSSINING
# 3208  SCHOOL DISTRICT                     45 INGHAM RD    BRIARCLIFF MANOR
# 3211  SCHOOL DISTRICT                      1031 ELM ST           PEEKSKILL
# 3214  SCHOOL DISTRICT                   18 FRANKLIN PL              PELHAM
# 3217  SCHOOL DISTRICT  411 THEODORE FREMD AVE, ST 1005                 RYE
# 3220  SCHOOL DISTRICT                  310 HORNIDGE RD          MAMARONECK
# 3223  SCHOOL DISTRICT                   113 BOWMAN AVE        PORT CHESTER
# 3226  SCHOOL DISTRICT                   390 N RIDGE ST           RYE BROOK
# 3229  SCHOOL DISTRICT                    2 BREWSTER RD           SCARSDALE
# 3232  SCHOOL DISTRICT                       334 RT 202              SOMERS
# 3235  SCHOOL DISTRICT                    5 HOMESIDE LN        WHITE PLAINS
# 3238  SCHOOL DISTRICT                     1 LARKIN CTR             YONKERS
# 3241  SCHOOL DISTRICT                     1086 MAIN ST           SHRUB OAK
# 3244  SCHOOL DISTRICT                 2725 CROMPOND RD    YORKTOWN HEIGHTS
# 3247  SCHOOL DISTRICT                   3338 E MAIN ST              ATTICA
# 3250  SCHOOL DISTRICT                   5550 SCHOOL RD         GAINESVILLE
# 3253  SCHOOL DISTRICT                       1225 RT 19             WYOMING
# 3256  SCHOOL DISTRICT                   33 WATKINS AVE               PERRY
# 3259  SCHOOL DISTRICT                 153 W BUFFALO ST              WARSAW
# 3262  SCHOOL DISTRICT                      1 SCHOOL DR            PENN YAN
# 3265  SCHOOL DISTRICT                      55 WATER ST              DUNDEE
# 3268           REGION                              NaN                 NaN
#
#      STATE  ZIP CODE                                         Location 1
# 1       NY   12143.0  15 MOUNTAIN RD\nRAVENA, NY 12143\n(42.47227638...
# 4       NY   12047.0  7 BEVAN ST\nCOHOES, NY 12047\n(42.771285452000...
# 7       NY   12205.0  102 LORALEE DR\nALBANY, NY 12205\n(42.73352407...
# 10      NY   12110.0  91 FIDDLERS LN\nLATHAM, NY 12110\n(42.72935391...
# 13      NY   12183.0  171 HUDSON AVE\nGREEN ISLAND, NY 12183\n(42.74...
# 16      NY   12085.0  8 SCHOOL RD\nGUILDERLAND CENTER, NY 12085\n(42...
# 19      NY   14804.0  6795 RT 21\nALMOND, NY 14804\n(42.295582036000...
# 22      NY   14822.0  4-8 MAIN ST\nCANASERAGA, NY 14822\n(42.4613066...
# 25      NY   14739.0  46 W MAIN ST\nFRIENDSHIP, NY 14739\n(42.206627...
# 28      NY   14897.0  692 MAIN ST\nWHITESVILLE, NY 14897\n(42.038002...
# 31      NY   14895.0  126 WEST STATE ST\nWELLSVILLE, NY 14895\n(42.1...
# 34      NY   14715.0  100 SCHOOL ST\nBOLIVAR, NY 14715\n(42.06531119...
# 37      NY   13901.0  1 GORDON DR\nBINGHAMTON, NY 13901\n(42.1924753...
# 40      NY   13901.0  164 HAWLEY ST\nBINGHAMTON, NY 13901\n(42.09891...
# 43      NY   13787.0  54 MAIN ST\nHARPURSVILLE, NY 13787\n(42.181771...
# 46      NY   13748.0  1040 CONKLIN RD\nCONKLIN, NY 13748\n(42.077514...
# 49      NY   13901.0  221 CHENANGO BRIDGE RD\nBINGHAMTON, NY 13901\n...
# 52      NY   13865.0  1191 NY RT 79\nWINDSOR, NY 13865\n(42.06669450...
# 55      NY   14706.0  3131 FIVE MILE RD\nALLEGANY, NY 14706\n(42.131...
# 58      NY   14731.0  5873 RT 219\nELLICOTTVILLE, NY 14731\n(42.2548...
# 61      NY   14743.0  3701 MAIN ST\nHINSDALE, NY 14743\n(42.16115107...
# 64      NY   14760.0  410 W SULLIVAN ST\nOLEAN, NY 14760\n(42.081507...
# 67      NY   14772.0  18 MAIN ST\nRANDOLPH, NY 14772\n(42.1645272580...
# 70      NY   14779.0  50 IROQUOIS DR\nSALAMANCA, NY 14779\n(42.16060...
# 73      NY   13166.0  2821 E BRUTUS ST\nWEEDSPORT, NY 13166\n(43.047...
# 76      NY   13033.0  2851 NYS RT 370\nCATO, NY 13033\n(43.183208405...
# 79      NY   13118.0  68 S MAIN ST\nMORAVIA, NY 13118\n(42.707012324...
# 82      NY   14738.0  26 INSTITUTE ST\nFREWSBURG, NY 14738\n(42.0542...
# 85      NY   14782.0  5935 RT 60\nSINCLAIRVILLE, NY 14782\n(42.25838...
# 88      NY   14724.0  8672 E MAIN ST\nCLYMER, NY 14724\n(42.02086768...
# ...    ...       ...                                                ...
# 3181    NY   10591.0                                (41.0991, -73.8312)
# 3184    NY   10595.0                                 (41.0927, -73.778)
# 3187    NY   10570.0                                (41.1338, -73.7858)
# 3190    NY   10553.0                                (40.9163, -73.8251)
# 3193    NY   10514.0                                (41.1763, -73.7546)
# 3196    NY   10801.0                                (40.9198, -73.7872)
# 3199    NY   10504.0                                (41.1343, -73.6865)
# 3202    NY   10560.0                                 (41.354, -73.5942)
# 3205    NY   10562.0                                 (41.167, -73.8472)
# 3208    NY   10510.0                                 (41.147, -73.8194)
# 3211    NY   10566.0                                (41.2864, -73.9172)
# 3214    NY   10803.0                                (40.9039, -73.8123)
# 3217    NY   10580.0                                (40.9766, -73.6976)
# 3220    NY   10543.0                                 (40.9572, -73.717)
# 3223    NY   10573.0                                (41.0042, -73.6888)
# 3226    NY   10573.0                                (41.0321, -73.6803)
# 3229    NY   10583.0                                (40.9953, -73.7949)
# 3232    NY   10589.0                                (41.3378, -73.6752)
# 3235    NY   10605.0                                (41.0074, -73.7336)
# 3238    NY   10701.0                                (40.9354, -73.8995)
# 3241    NY   10588.0                                (41.3296, -73.8282)
# 3244    NY   10598.0                                (41.2948, -73.8023)
# 3247    NY   14011.0                                (42.8618, -78.2603)
# 3250    NY   14066.0                                (42.6301, -78.1154)
# 3253    NY   14591.0                                (42.8213, -78.0944)
# 3256    NY   14530.0                                 (42.7236, -78.003)
# 3259    NY   14569.0                                (42.7403, -78.1382)
# 3262    NY   14527.0                                 (42.6671, -77.063)
# 3265    NY   14837.0                                (42.5263, -76.9771)
# 3268   NaN       NaN                                                NaN
#
# [1090 rows x 18 columns]

# %%
# Convertir a mayúsculas.
df['AREA NAME'][0:5].str.upper()
# Out:
# 0    RAVENA COEYMANS SELKIRK CENTRAL SCHOOL DISTRICT
# 1    RAVENA COEYMANS SELKIRK CENTRAL SCHOOL DISTRICT
# 2    RAVENA COEYMANS SELKIRK CENTRAL SCHOOL DISTRICT
# 3                        COHOES CITY SCHOOL DISTRICT
# 4                        COHOES CITY SCHOOL DISTRICT
# Name: AREA NAME, dtype: object

# %%
# Convertir a minúsculas.
df['AREA NAME'][0:5].str.lower()
# Out:
# 0    ravena coeymans selkirk central school district
# 1    ravena coeymans selkirk central school district
# 2    ravena coeymans selkirk central school district
# 3                        cohoes city school district
# 4                        cohoes city school district
# Name: AREA NAME, dtype: object

# %%
# Cuantificar la cantidad de caracteres de cada elemento.
df['AREA NAME'][0:5].str.len()
# Out:
# 0    47
# 1    47
# 2    47
# 3    27
# 4    27
# Name: AREA NAME, dtype: int64

# %%
# Cortar en base a espacios en blanco.
df['AREA NAME'][0:5].str.split(' ')
# Out:
# 0    [RAVENA, COEYMANS, SELKIRK, CENTRAL, SCHOOL, D...
# 1    [RAVENA, COEYMANS, SELKIRK, CENTRAL, SCHOOL, D...
# 2    [RAVENA, COEYMANS, SELKIRK, CENTRAL, SCHOOL, D...
# 3                     [COHOES, CITY, SCHOOL, DISTRICT]
# 4                     [COHOES, CITY, SCHOOL, DISTRICT]
# Name: AREA NAME, dtype: object

# %%
# Reemplazar
df['AREA NAME'][0:5].str.replace('DISTRICT$', 'DIST')
# Out:
# 0    RAVENA COEYMANS SELKIRK CENTRAL SCHOOL DIST
# 1    RAVENA COEYMANS SELKIRK CENTRAL SCHOOL DIST
# 2    RAVENA COEYMANS SELKIRK CENTRAL SCHOOL DIST
# 3                        COHOES CITY SCHOOL DIST
# 4                        COHOES CITY SCHOOL DIST
# Name: AREA NAME, dtype: object

# %% [markdown]
# # 4. Agregación de datos

# %%
# Seleccionamos los 5 primeros registros de 2 campos.
d[['AREA NAME', 'COUNTY']][0:5]
# Out:
#                                          AREA NAME  COUNTY
# 0  RAVENA COEYMANS SELKIRK CENTRAL SCHOOL DISTRICT  ALBANY
# 1  RAVENA COEYMANS SELKIRK CENTRAL SCHOOL DISTRICT  ALBANY
# 2  RAVENA COEYMANS SELKIRK CENTRAL SCHOOL DISTRICT  ALBANY
# 3                      COHOES CITY SCHOOL DISTRICT  ALBANY
# 4                      COHOES CITY SCHOOL DISTRICT  ALBANY

# %%
# Partir los datos en dos grupos. Concatenarlos por posición.
p1 = d[['AREA NAME', 'COUNTY']][0:2] 
p1
# Out:
#                                          AREA NAME  COUNTY
# 0  RAVENA COEYMANS SELKIRK CENTRAL SCHOOL DISTRICT  ALBANY
# 1  RAVENA COEYMANS SELKIRK CENTRAL SCHOOL DISTRICT  ALBANY

# %%
p2 = d[['AREA NAME', 'COUNTY']][2:5]
p2
# Out:
#                                          AREA NAME  COUNTY
# 2  RAVENA COEYMANS SELKIRK CENTRAL SCHOOL DISTRICT  ALBANY
# 3                      COHOES CITY SCHOOL DISTRICT  ALBANY
# 4                      COHOES CITY SCHOOL DISTRICT  ALBANY

# %%
pd.concat([p1,p2],axis=0)
# Out:
#                                          AREA NAME  COUNTY
# 0  RAVENA COEYMANS SELKIRK CENTRAL SCHOOL DISTRICT  ALBANY
# 1  RAVENA COEYMANS SELKIRK CENTRAL SCHOOL DISTRICT  ALBANY
# 2  RAVENA COEYMANS SELKIRK CENTRAL SCHOOL DISTRICT  ALBANY
# 3                      COHOES CITY SCHOOL DISTRICT  ALBANY
# 4                      COHOES CITY SCHOOL DISTRICT  ALBANY

# %%
# Concatenar datos en base a una llave.
concatenated = pd.concat([p1,p2], keys = ['p1','p2'])
concatenated.head()
# Out:
#                                             AREA NAME  COUNTY
# p1 0  RAVENA COEYMANS SELKIRK CENTRAL SCHOOL DISTRICT  ALBANY
#    1  RAVENA COEYMANS SELKIRK CENTRAL SCHOOL DISTRICT  ALBANY
# p2 2  RAVENA COEYMANS SELKIRK CENTRAL SCHOOL DISTRICT  ALBANY
#    3                      COHOES CITY SCHOOL DISTRICT  ALBANY
#    4                      COHOES CITY SCHOOL DISTRICT  ALBANY

# %%
# Seleccionar la data agregada en base a una llave.
concatenated.loc['p1']
# Out:
#                                          AREA NAME  COUNTY
# 0  RAVENA COEYMANS SELKIRK CENTRAL SCHOOL DISTRICT  ALBANY
# 1  RAVENA COEYMANS SELKIRK CENTRAL SCHOOL DISTRICT  ALBANY

# %%
# Seleccionamos un subconjunto de elementos y promediamos.
data = df[df['GRADE LEVEL'] == 'ELEMENTARY']
data.head()
# Out:
#     LOCATION CODE  COUNTY                                        AREA NAME  \
# 1           10402  ALBANY  RAVENA COEYMANS SELKIRK CENTRAL SCHOOL DISTRICT
# 4           10500  ALBANY                      COHOES CITY SCHOOL DISTRICT
# 7           10601  ALBANY            SOUTH COLONIE CENTRAL SCHOOL DISTRICT
# 10          10623  ALBANY            NORTH COLONIE CENTRAL SCHOOL DISTRICT
# 13          10701  ALBANY          GREEN ISLAND UNION FREE SCHOOL DISTRICT
#
#                    REGION SCHOOL YEARS  NO. OVERWEIGHT PCT OVERWEIGHT  \
# 1   NORTHEASTERN NEW YORK    2012-2013            74.0          19.2%
# 4   NORTHEASTERN NEW YORK    2012-2013            58.0          16.1%
# 7   NORTHEASTERN NEW YORK    2012-2013           145.0          17.4%
# 10  NORTHEASTERN NEW YORK    2012-2013            94.0          15.5%
# 13  NORTHEASTERN NEW YORK    2012-2013             NaN            NaN
#
#     NO. OBESE PCT OBESE  NO. OVERWEIGHT OR OBESE PCT OVERWEIGHT OR OBESE  \
# 1        72.0     18.7%                    146.0                   37.9%
# 4        89.0     24.7%                    147.0                   40.8%
# 7       169.0     20.3%                    314.0                   37.8%
# 10       78.0     12.9%                    172.0                   28.4%
# 13       15.0     35.7%                     15.0                   35.7%
#
#    GRADE LEVEL        AREA TYPE  STREET ADDRESS          CITY STATE  ZIP CODE  \
# 1   ELEMENTARY  SCHOOL DISTRICT  15 MOUNTAIN RD        RAVENA    NY   12143.0
# 4   ELEMENTARY  SCHOOL DISTRICT      7 BEVAN ST        COHOES    NY   12047.0
# 7   ELEMENTARY  SCHOOL DISTRICT  102 LORALEE DR        ALBANY    NY   12205.0
# 10  ELEMENTARY  SCHOOL DISTRICT  91 FIDDLERS LN        LATHAM    NY   12110.0
# 13  ELEMENTARY  SCHOOL DISTRICT  171 HUDSON AVE  GREEN ISLAND    NY   12183.0
#
#                                            Location 1
# 1   15 MOUNTAIN RD\nRAVENA, NY 12143\n(42.47227638...
# 4   7 BEVAN ST\nCOHOES, NY 12047\n(42.771285452000...
# 7   102 LORALEE DR\nALBANY, NY 12205\n(42.73352407...
# 10  91 FIDDLERS LN\nLATHAM, NY 12110\n(42.72935391...
# 13  171 HUDSON AVE\nGREEN ISLAND, NY 12183\n(42.74...

# %%
data['NO. OBESE'].mean()
# Out:
# 213.4159378036929

# %%
# La suma total.
data['NO. OBESE'].sum()
# Out:
# 219605.0

# %%
# Valor máximo.
data['NO. OBESE'].max()
# Out:
# 48843.0

# %%
# Valor mínimo.
data['NO. OBESE'].min()
# Out:
# 5.0

# %%
# Desviación Estándar.
data['NO. OBESE'].std()
# Out:
# 1690.3831128098109

# %%
# Conteo.
data = df[(df['GRADE LEVEL'] == 'ELEMENTARY') & (df['COUNTY'] == 'DELAWARE')]
data['COUNTY'].count()
# Out:
# 19

# %%
data['GRADE LEVEL'].count()
# Out:
# 19

# %%
# Crear datos
grade_lookup = {'GRADE': pd.Series(['ELEMENTARY','MIDDLE/HIGH', 'MISC']),'LEVEL': pd.Series([1, 2, 3])}
grade_lookup
# Out:
# {'GRADE': 0     ELEMENTARY
#  1    MIDDLE/HIGH
#  2           MISC
#  dtype: object, 'LEVEL': 0    1
#  1    2
#  2    3
#  dtype: int64}

# %%
grade_lookup2 = pd.DataFrame(grade_lookup)
grade_lookup2
# Out:
#          GRADE  LEVEL
# 0   ELEMENTARY      1
# 1  MIDDLE/HIGH      2
# 2         MISC      3

# %%
# Primeros 5 elementos del campo GRADE LEVEL
df[['GRADE LEVEL']][0:7]
# Out:
#       GRADE LEVEL
# 0  DISTRICT TOTAL
# 1      ELEMENTARY
# 2     MIDDLE/HIGH
# 3  DISTRICT TOTAL
# 4      ELEMENTARY
# 5     MIDDLE/HIGH
# 6  DISTRICT TOTAL

# %%
# Inner Join
d_sub = df[0:5].join(grade_lookup2.set_index(['GRADE']),on=['GRADE LEVEL'], how='inner')
d_sub
# Out:
#    LOCATION CODE  COUNTY                                        AREA NAME  \
# 1          10402  ALBANY  RAVENA COEYMANS SELKIRK CENTRAL SCHOOL DISTRICT
# 4          10500  ALBANY                      COHOES CITY SCHOOL DISTRICT
# 2          10402  ALBANY  RAVENA COEYMANS SELKIRK CENTRAL SCHOOL DISTRICT
#
#                   REGION SCHOOL YEARS  NO. OVERWEIGHT PCT OVERWEIGHT  \
# 1  NORTHEASTERN NEW YORK    2012-2013            74.0          19.2%
# 4  NORTHEASTERN NEW YORK    2012-2013            58.0          16.1%
# 2  NORTHEASTERN NEW YORK    2012-2013            50.0          17.6%
#
#    NO. OBESE PCT OBESE  NO. OVERWEIGHT OR OBESE PCT OVERWEIGHT OR OBESE  \
# 1       72.0     18.7%                    146.0                   37.9%
# 4       89.0     24.7%                    147.0                   40.8%
# 2       67.0     23.6%                    117.0                   41.2%
#
#    GRADE LEVEL        AREA TYPE  STREET ADDRESS    CITY STATE  ZIP CODE  \
# 1   ELEMENTARY  SCHOOL DISTRICT  15 MOUNTAIN RD  RAVENA    NY   12143.0
# 4   ELEMENTARY  SCHOOL DISTRICT      7 BEVAN ST  COHOES    NY   12047.0
# 2  MIDDLE/HIGH  SCHOOL DISTRICT  15 MOUNTAIN RD  RAVENA    NY   12143.0
#
#                                           Location 1  LEVEL
# 1  15 MOUNTAIN RD\nRAVENA, NY 12143\n(42.47227638...      1
# 4  7 BEVAN ST\nCOHOES, NY 12047\n(42.771285452000...      1
# 2  15 MOUNTAIN RD\nRAVENA, NY 12143\n(42.47227638...      2

# %%
#Left Join.
d_sub = df[0:5].join(grade_lookup2.set_index(['GRADE']),on=['GRADE LEVEL'], how='left')
d_sub
# Out:
#    LOCATION CODE  COUNTY                                        AREA NAME  \
# 0          10402  ALBANY  RAVENA COEYMANS SELKIRK CENTRAL SCHOOL DISTRICT
# 1          10402  ALBANY  RAVENA COEYMANS SELKIRK CENTRAL SCHOOL DISTRICT
# 2          10402  ALBANY  RAVENA COEYMANS SELKIRK CENTRAL SCHOOL DISTRICT
# 3          10500  ALBANY                      COHOES CITY SCHOOL DISTRICT
# 4          10500  ALBANY                      COHOES CITY SCHOOL DISTRICT
#
#                   REGION SCHOOL YEARS  NO. OVERWEIGHT PCT OVERWEIGHT  \
# 0  NORTHEASTERN NEW YORK    2012-2013           124.0          18.5%
# 1  NORTHEASTERN NEW YORK    2012-2013            74.0          19.2%
# 2  NORTHEASTERN NEW YORK    2012-2013            50.0          17.6%
# 3  NORTHEASTERN NEW YORK    2012-2013            84.0          17.2%
# 4  NORTHEASTERN NEW YORK    2012-2013            58.0          16.1%
#
#    NO. OBESE PCT OBESE  NO. OVERWEIGHT OR OBESE PCT OVERWEIGHT OR OBESE  \
# 0      139.0     20.8%                    263.0                   39.3%
# 1       72.0     18.7%                    146.0                   37.9%
# 2       67.0     23.6%                    117.0                   41.2%
# 3      124.0     25.4%                    208.0                   42.5%
# 4       89.0     24.7%                    147.0                   40.8%
#
#       GRADE LEVEL        AREA TYPE  STREET ADDRESS    CITY STATE  ZIP CODE  \
# 0  DISTRICT TOTAL  SCHOOL DISTRICT  15 MOUNTAIN RD  RAVENA    NY   12143.0
# 1      ELEMENTARY  SCHOOL DISTRICT  15 MOUNTAIN RD  RAVENA    NY   12143.0
# 2     MIDDLE/HIGH  SCHOOL DISTRICT  15 MOUNTAIN RD  RAVENA    NY   12143.0
# 3  DISTRICT TOTAL  SCHOOL DISTRICT      7 BEVAN ST  COHOES    NY   12047.0
# 4      ELEMENTARY  SCHOOL DISTRICT      7 BEVAN ST  COHOES    NY   12047.0
#
#                                           Location 1  LEVEL
# 0  15 MOUNTAIN RD\nRAVENA, NY 12143\n(42.47227638...    NaN
# 1  15 MOUNTAIN RD\nRAVENA, NY 12143\n(42.47227638...    1.0
# 2  15 MOUNTAIN RD\nRAVENA, NY 12143\n(42.47227638...    2.0
# 3  7 BEVAN ST\nCOHOES, NY 12047\n(42.771285452000...    NaN
# 4  7 BEVAN ST\nCOHOES, NY 12047\n(42.771285452000...    1.0

# %%
#Full Outer Join.
d_sub = df[0:5].join(grade_lookup2.set_index(['GRADE LEVEL']),on=['GRADE LEVEL'], how='outer')
d_sub
# Out:
#    LOCATION CODE  COUNTY                                        AREA NAME  \
# 0        10402.0  ALBANY  RAVENA COEYMANS SELKIRK CENTRAL SCHOOL DISTRICT
# 3        10500.0  ALBANY                      COHOES CITY SCHOOL DISTRICT
# 1        10402.0  ALBANY  RAVENA COEYMANS SELKIRK CENTRAL SCHOOL DISTRICT
# 4        10500.0  ALBANY                      COHOES CITY SCHOOL DISTRICT
# 2        10402.0  ALBANY  RAVENA COEYMANS SELKIRK CENTRAL SCHOOL DISTRICT
# 4            NaN     NaN                                              NaN
#
#                   REGION SCHOOL YEARS  NO. OVERWEIGHT PCT OVERWEIGHT  \
# 0  NORTHEASTERN NEW YORK    2012-2013           124.0          18.5%
# 3  NORTHEASTERN NEW YORK    2012-2013            84.0          17.2%
# 1  NORTHEASTERN NEW YORK    2012-2013            74.0          19.2%
# 4  NORTHEASTERN NEW YORK    2012-2013            58.0          16.1%
# 2  NORTHEASTERN NEW YORK    2012-2013            50.0          17.6%
# 4                    NaN          NaN             NaN            NaN
#
#    NO. OBESE PCT OBESE  NO. OVERWEIGHT OR OBESE PCT OVERWEIGHT OR OBESE  \
# 0      139.0     20.8%                    263.0                   39.3%
# 3      124.0     25.4%                    208.0                   42.5%
# 1       72.0     18.7%                    146.0                   37.9%
# 4       89.0     24.7%                    147.0                   40.8%
# 2       67.0     23.6%                    117.0                   41.2%
# 4        NaN       NaN                      NaN                     NaN
#
#       GRADE LEVEL        AREA TYPE  STREET ADDRESS    CITY STATE  ZIP CODE  \
# 0  DISTRICT TOTAL  SCHOOL DISTRICT  15 MOUNTAIN RD  RAVENA    NY   12143.0
# 3  DISTRICT TOTAL  SCHOOL DISTRICT      7 BEVAN ST  COHOES    NY   12047.0
# 1      ELEMENTARY  SCHOOL DISTRICT  15 MOUNTAIN RD  RAVENA    NY   12143.0
# 4      ELEMENTARY  SCHOOL DISTRICT      7 BEVAN ST  COHOES    NY   12047.0
# 2     MIDDLE/HIGH  SCHOOL DISTRICT  15 MOUNTAIN RD  RAVENA    NY   12143.0
# 4            MISC              NaN             NaN     NaN   NaN       NaN
#
#                                           Location 1  LEVEL
# 0  15 MOUNTAIN RD\nRAVENA, NY 12143\n(42.47227638...    NaN
# 3  7 BEVAN ST\nCOHOES, NY 12047\n(42.771285452000...    NaN
# 1  15 MOUNTAIN RD\nRAVENA, NY 12143\n(42.47227638...    1.0
# 4  7 BEVAN ST\nCOHOES, NY 12047\n(42.771285452000...    1.0
# 2  15 MOUNTAIN RD\nRAVENA, NY 12143\n(42.47227638...    2.0
# 4                                                NaN    3.0

# %%
# Group By
df['NO. OBESE'].groupby(d['GRADE LEVEL']).sum()
# Out:
# GRADE LEVEL
# DISTRICT TOTAL    127101.0
# ELEMENTARY         72880.0
# MIDDLE/HIGH        53089.0
# Name: NO. OBESE, dtype: float64

# %%
df.groupby('GRADE LEVEL')['NO. OBESE'].mean()
# Out:
# GRADE LEVEL
# DISTRICT TOTAL    359.972590
# ELEMENTARY        213.415938
# MIDDLE/HIGH       162.943147
# Name: NO. OBESE, dtype: float64

# %%
df['NO. OBESE'].groupby(df['GRADE LEVEL']).aggregate(sum)
# Out:
# GRADE LEVEL
# DISTRICT TOTAL    380851.0
# ELEMENTARY        219605.0
# MIDDLE/HIGH       160499.0
# Name: NO. OBESE, dtype: float64

# %%
df['NO. OBESE'].groupby(df['GRADE LEVEL']).std()
# Out:
# GRADE LEVEL
# DISTRICT TOTAL    2875.820653
# ELEMENTARY        1690.383113
# MIDDLE/HIGH       1252.104878
# Name: NO. OBESE, dtype: float64
